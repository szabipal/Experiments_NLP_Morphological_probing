# %% [markdown]
# # Inference of the English marker representations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
file_path='/content/drive/My Drive/Colab Notebooks/English_raw_data/'

# %%
keys=['plural_noun_sentences', 'third_person_present_sentences', 'accusative_case_sentences', 'genitive_case_sentences', 'dative_case_sentences', 'sublative_case_sentences', 'translative_case_sentences', 'causal_final_case_sentences']

# %%
import pandas as pd
dfs={}
for key in keys:
    df_path=file_path + f'{key}.csv'
    dfs[key]=pd.read_csv(df_path)

# %%
def read_data_as_sentence(file_path):
    """
    Parses the CoNNL-U Plus file and returns a dataframe of sentences.
    Extracting features from the data and return a dataframe of sentence's Input_form list and sentence's arguments list.

    Returns a dataframe, where each row represents one sentence with its all words and all features of words (each columns is a list with lengh of number of words in sentence).

    file_path (str): The file path to the data to be preprocessed.
    output_path (str): The file path to the save processed dataframe.
    """
    # sentences list for all sentence in data file
    sentences = []
    # sentence list for all token in each sentence
    sentence = []  # Initialize an empty list for the current sentence
    # Open data file
    with open(file_path, 'r', encoding="utf8") as file:
        # For each line in data file
        for line in file:
            # split line by TAB (\t)
            line = line.strip().split('\t')
            # If the line starts with '#', it's a comment, ignore it
            if line[0].startswith('#'):
                continue
            # If the line is not empty
            elif line[0].strip() != '':

                # Create a token if its ID does not contain a period
                # Each token only has form, predicate, and arguments (argument per each predicate of sentence)
                if '.' not in line[0] and len(line) > 10:
                    token = {
                        'id': line[0],
                        'form': line[1],
                        'lemma': line[2],
                        'upos': line[3],
                        'xpos': line[4],
                        'head': line[6],
                        'dependency_relation': line[7],
                        'dependency_graph': line[8],
                        'miscellaneous': line[9],
                        'predicate': line[10],
                        'argument': line[11:]  # Store all remaining elements as arguments.
                    }
                    # Append the token to the sentence.
                    sentence.append(token)
# A new line indicates the end of a sentence.
            # If line is empty one sentence has been finished.
            elif line[0].strip() == '':
                # Append the completed sentence to the sentences list.
                sentences.append(sentence)
                # Reset sentence for the next sentence.
                sentence = []
    print(f'num of sentences before duplication{len(sentences)}\n')
    # Iterate over all sentences. Create copies of sentences for each predicate.
    expanded_sentences = []
    for sentence in sentences:
        # Find all predicates in the sentence.
        predicates = [token['predicate'] for token in sentence if token['predicate'] != '_']

        # Skip sentences that do not contain any predicates
        if len(predicates) == 0:
            continue

        # For every predicate, create a copy of the sentence.
        for index, predicate in enumerate(predicates):
            # For each predicate in the sentence, we make a copy of the sentence.
            sentence_copy = [token.copy() for token in sentence]
            # Finding the predicate 'form' of the sentence predicate.
            predicate_form = [token['form'] for token in sentence_copy if token['predicate'] == predicate]
            for token in sentence_copy:
                token['predicate'] = predicate_form[0]

                # Keep only the relevant argument for this predicate. Overwrite 'V' and 'C-V' with '_'.
                if token['argument'][index] == 'V' or token['argument'][index] == 'C-V':
                    token['argument'] = '_'
                else:
                    token['argument'] = token['argument'][index]

            expanded_sentences.append(sentence_copy)

    print(f'num of sentences after duplication {len(expanded_sentences)}\n')
    print(f'the difference between the two is {len(expanded_sentences) - len(sentences)}')

    return expanded_sentences

# %%
file_path=f'{file_path}en_ewt-up-train.conllu'

# %%
sents=read_data_as_sentence(file_path)
# Out:
# num of sentences before duplication12543
#
# num of sentences after duplication 40482
#
# the difference between the two is 27939

# %% [markdown]
# ## Preprocessing of the English data to include the needed information

# %%
def create_sentence_dfs(sentences):
    """
    Converts each sentence (a list of token dictionaries) into a DataFrame.

    Parameters:
        sentences (list of list of dict): A list containing sentences, where each sentence is a list of token dictionaries.

    Returns:
        list of pd.DataFrame: A list of DataFrames, each representing a sentence.
    """
    # Convert each sentence (list of dictionaries) into a DataFrame
    sentence_dfs = [pd.DataFrame(sentence) for sentence in sentences]
    return sentence_dfs

# %%
sentences=create_sentence_dfs(sents)

# %%
import pandas as pd

def add_head_srl_labels(sentence_df):
    """
    Adds the semantic role label of the head for each token in the DataFrame.

    Parameters:
        sentence_df (pd.DataFrame): DataFrame representing a sentence with token-level information, including 'head' and 'argument'.

    Returns:
        pd.DataFrame: The input DataFrame with an additional 'head_srl_label' column.
    """
    # Create a dictionary to map each token's ID to its SRL label
    srl_label_dict = sentence_df.set_index('id')['argument'].to_dict()

    # Initialize a list to store the head SRL labels for each token
    head_srl_labels = []

    # For each token, find the SRL label of its head
    for _, row in sentence_df.iterrows():
        head_id = row['head']  # Get the head ID of the token
        # Get the SRL label of the head, or "_" if the head is not in the dictionary (e.g., root of the sentence)
        head_srl_label = srl_label_dict.get(head_id, "_")
        head_srl_labels.append(head_srl_label)

    # Add the head SRL labels as a new column in the DataFrame
    sentence_df['head_srl_label'] = head_srl_labels
    return sentence_df



# Generate DataFrames for each sentence
sentence_dfs = [pd.DataFrame(sentence) for sentence in sents]

# Apply the head SRL labeling to each sentence DataFrame
labeled_sentence_dfs = [add_head_srl_labels(df) for df in sentence_dfs]

# Print each DataFrame with the new head SRL labels to verify

# %%
import spacy
import pandas as pd

# Load the spaCy model for morphology
nlp = spacy.load("en_core_web_sm")

def add_morphological_info(sentence_dfs):
    """
    Adds morphological information to each token in each sentence DataFrame
    and includes the original sentence as a new column 'text'.

    Parameters:
        sentence_dfs (list of pd.DataFrame): A list of DataFrames representing sentences, each containing token-level information.

    Returns:
        list of pd.DataFrame: A list of DataFrames with morphological information and original sentence added.
    """
    updated_sentence_dfs = []
    for df in sentence_dfs:
        # Join tokens into a single sentence for spaCy processing
        sentence_text = " ".join(df['form'])
        doc = nlp(sentence_text)

        # Ensure token alignment by matching spaCy tokens to DataFrame rows
        morphs = [token.morph.to_dict() for token in doc]

        # Check if spaCy token count matches DataFrame row count
        if len(morphs) == len(df):
            df = df.copy()  # Make a copy to avoid modifying the original DataFrame
            df['morph'] = morphs
            df['text'] = sentence_text  # Add the full sentence as a new column
            updated_sentence_dfs.append(df)

    return updated_sentence_dfs

# Run the morphological analyzer and add the morph column to each sentence DataFrame
sentence_dfs_with_morph = add_morphological_info(labeled_sentence_dfs)

def filter_sentences(sentence_dfs):
    plural_noun_sentences = []
    third_person_present_sentences = []
    accusative_case_sentences = []
    genitive_case_sentences = []
    dative_case_sentences = []
    sublative_case_sentences = []
    translative_case_sentences = []
    causal_final_case_sentences = []

    for df in sentence_dfs:
        add_head_srl_labels(df)  # Ensure head SRL labels are added only once per DataFrame

        # 1. Plural marker on nouns
        if df[(df['upos'] == 'NOUN') & (df['morph'].apply(lambda x: x.get('Number') == 'Plur'))].shape[0] > 0:
            plural_noun_sentences.append(df)

        # 2. Third-person present tense verb conjugation
        if df[(df['upos'] == 'VERB') & (df['morph'].apply(lambda x: x.get('Person') == '3')) & (df['morph'].apply(lambda x: x.get('Tense') == 'Pres'))].shape[0] > 0:
            third_person_present_sentences.append(df)

        # 3. Accusative case for "him", "them", "me" with ARG1 SRL label
        if df[(df['form'].isin(['him', 'them', 'me'])) & (df['argument'] == 'ARG1')].shape[0] > 0:
            accusative_case_sentences.append(df)

        # 4. Genitive case signaled by possessive marker 's
        if df['form'].str.endswith("'s").any():
            genitive_case_sentences.append(df)

        # 5. Dative case with "to" or "for" and head labeled ARG2
        if df[(df['form'].isin(['to', 'for'])) & (df['head_srl_label'] == 'ARG2')].shape[0] > 0:
            dative_case_sentences.append(df)

        # 6. Sublative case with "onto" preposition
        if (df['form'] == 'on').any():
            sublative_case_sentences.append(df)

        # 7. Translative case with "into" preposition
        if (df['form'] == 'into').any():
            translative_case_sentences.append(df)

        # 8. Causal-final case with "for" preposition, where head is not ARG2
        if df[(df['form'] == 'for') & (df['head_srl_label'] != 'ARG2')].shape[0] > 0:
            causal_final_case_sentences.append(df)

    return {
        "plural_noun_sentences": plural_noun_sentences,
        "third_person_present_sentences": third_person_present_sentences,
        "accusative_case_sentences": accusative_case_sentences,
        "genitive_case_sentences": genitive_case_sentences,
        "dative_case_sentences": dative_case_sentences,
        "sublative_case_sentences": sublative_case_sentences,
        "translative_case_sentences": translative_case_sentences,
        "causal_final_case_sentences": causal_final_case_sentences
    }

# Apply the filtering with morphological information
filtered_sentences = filter_sentences(sentence_dfs_with_morph)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
import pandas as pd
import spacy
from transformers import BertTokenizer

# Load the spaCy model for English
nlp = spacy.load("en_core_web_sm")

# Load the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def extract_target_morpheme_subtoken(sentence, doc, bert_subtokens, bert_token_ids):
    # Track the subtoken index
    subtoken_idx = 0

    # Iterate through each token in the spaCy doc and identify the first target token
    for token in doc:
        morph = token.morph
        form = token.text
        lemma = token.lemma_
        morpheme_diff = len(form) - len(lemma) if form != lemma else 0

        # Tokenize only the word form to find the subtoken range
        word_subtokens = tokenizer.tokenize(form)
        word_subtoken_ids = tokenizer.convert_tokens_to_ids(word_subtokens)

        # Calculate the subtoken start and end index for the token
        subtoken_start_idx = subtoken_idx
        subtoken_end_idx = subtoken_idx + len(word_subtokens) - 1

        # Identify if this token matches any target criteria
        target_class = None
        if token.pos_ == 'NOUN' and morph.get("Number") == ["Plur"]:
            target_class = "Plural Noun"
        elif token.pos_ == 'VERB' and morph.get("Person") == ["3"] and morph.get("Tense") == ["Pres"]:
            target_class = "Third-Person Present Tense Verb"
        elif token.text in ['him', 'them', 'me'] and token.ent_type_ == 'ARG1':
            target_class = "Accusative Case"
        elif token.text.endswith("'s"):
            target_class = "Genitive Case"
        elif token.text in ['to', 'for'] and token.head.ent_type_ == 'ARG2':
            target_class = "Dative Case"
        elif token.text == 'on':
            target_class = "Sublative Case"
        elif token.text == 'into':
            target_class = "Translative Case"
        elif token.text == 'for' and token.head.ent_type_ != 'ARG2':
            target_class = "Causal-Final Case"

        # If this is a target token, create a row and break to prevent multiple rows per sentence
        if target_class:
            target_row = {
                "Word": form,
                "Lemma": lemma,
                "POS": token.pos_,
                "Case": morph.get("Case")[0] if morph.get("Case") else None,
                "Number": morph.get("Number")[0] if morph.get("Number") else None,
                "Person": morph.get("Person")[0] if morph.get("Person") else None,
                "Tense": morph.get("Tense")[0] if morph.get("Tense") else None,
                "Mood": morph.get("Mood")[0] if morph.get("Mood") else None,
                "Voice": morph.get("Voice")[0] if morph.get("Voice") else None,
                "Form-Lemma Difference": morpheme_diff,
                "Subtokens": word_subtokens,
                "Subtoken IDs": word_subtoken_ids,
                "Subtoken Start Index": subtoken_start_idx,
                "Subtoken End Index": subtoken_end_idx,
                "Target Class": target_class,
                "BERT Subtokenized Sentence": ' '.join(bert_subtokens),
                "Sentence": sentence
            }
            return target_row  # Return immediately after finding the first target token

        # Update subtoken index for the next token
        subtoken_idx += len(word_subtokens)

    return None  # Return None if no target token is found

# Function to process a list of DataFrames with sentences
def process_target_instances(df_list, sentence_column, nlp, tokenizer):
    # Ensure unique sentences are processed
    unique_sentences = set()

    target_rows = []  # List to store only the target rows

    for df in df_list:
        # Drop duplicate rows within each DataFrame
        df = df.drop_duplicates(subset=[sentence_column])

        for index, row in df.iterrows():
            sentence = row[sentence_column]

            # Skip if this sentence has already been processed
            if sentence in unique_sentences:
                continue
            unique_sentences.add(sentence)

            # Process the sentence with spaCy and BERT
            doc = nlp(sentence)
            bert_subtokens = tokenizer.tokenize(sentence)
            bert_token_ids = tokenizer.convert_tokens_to_ids(bert_subtokens)

            target_row = extract_target_morpheme_subtoken(sentence, doc, bert_subtokens, bert_token_ids)

            # Append only if a target row was found
            if target_row:
                target_rows.append(target_row)

    # Convert the list of target rows to a DataFrame
    target_instances_df = pd.DataFrame(target_rows)

    return target_instances_df

# Example usage with a list of DataFrames (e.g., filtered_sentences values)
# final_target_df = process_target_instances(filtered_sentences_list, 'text', nlp, tokenizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
target_items={}
full_items=[]
for key, value in filtered_sentences.items():



    final_target_df = process_target_instances(value[:-1], 'text', nlp, tokenizer)

    target_items[key]=final_target_df
    #full_items.append(df_morphemes_with_subtokens)

# %%
# Create a new dictionary to store deduplicated copies
deduplicated_target_items = {}

for key, value in target_items.items():
    # Make a copy of the DataFrame to avoid modifying the original
    df_copy = value.copy()
    print(key)
    print(len(value))
    print()
    # Remove duplicates on the copy
    # Replace 'column_with_list1' and 'column_with_list2' with actual column names if needed
    deduplicated_df = df_copy.drop_duplicates(subset=[col for col in df_copy.columns if not isinstance(df_copy[col].iloc[0], list)])
    print(len(deduplicated_df))
    # Store the deduplicated DataFrame in the new dictionary
    deduplicated_target_items[key] = deduplicated_df

# Now `deduplicated_target_items` contains the deduplicated DataFrames without modifying `target_items`.
# Out:
# plural_noun_sentences
# 4346
#
# 4346
# third_person_present_sentences
# 1238
#
# 1238
# accusative_case_sentences
# 326
#
# 326
# genitive_case_sentences
# 737
#
# 737
# dative_case_sentences
# 1025
#
# 1025
# sublative_case_sentences
# 948
#
# 948
# translative_case_sentences
# 175
#
# 175
# causal_final_case_sentences
# 1388
#
# 1388

# %%
import torch
import numpy as np
import pickle
from transformers import BertTokenizer, BertModel

# Load the English BERT tokenizer and model with hidden states enabled
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased", output_hidden_states=True)

# Move the model to GPU
model = model.to('cuda')

# Ensure the model is in evaluation mode
model.eval()

def extract_bert_hidden_representations(df, output_file="representations_english.pkl", model=model, tokenizer=tokenizer):
    # Use half of the dataset
    df_half = df.sample(frac=0.5, random_state=42)  # Using half of the dataset

    representations = []  # List to store all representations in memory

    for idx, row in df_half.iterrows():
        sentence = row['Sentence']
        encoded_input = tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=512, add_special_tokens=True)

        # Move tokenized input to GPU
        encoded_input = {key: value.to('cuda') for key, value in encoded_input.items()}

        # Process the sentence
        with torch.no_grad():
            outputs = model(**encoded_input)
            all_hidden_states = outputs.hidden_states

        # Get the length of the tokenized sentence (excluding padding)
        tokenized_length = (encoded_input['input_ids'] != tokenizer.pad_token_id).sum(dim=1) - 2

        subtoken_end_idx = row['Subtoken End Index']

        # Ensure subtoken_end_idx is within the tokenized length for this sentence
        if subtoken_end_idx > tokenized_length.item():
            print(f"Skipping token '{row['Word']}' in sentence '{row['Sentence']}' because subtoken_end_idx exceeds tokenized length.")
            torch.cuda.empty_cache()  # Clear GPU memory
            continue

        # Extract hidden states for the given subtoken end index for all layers
        token_representations_all_layers = [layer_output[0, subtoken_end_idx + 1, :].cpu().numpy() for layer_output in all_hidden_states]

        # Create the dictionary for the current sentence
        representation = {
            'Word': row['Word'],
            'Lemma': row['Lemma'],
            'Sentence': row['Sentence'],
            'Hidden Representations (All Layers)': token_representations_all_layers
        }

        # Save each sentence's representation to file incrementally
        with open(output_file, 'ab') as f:
            pickle.dump(representation, f)

        # Add to the list to keep in memory
        representations.append(representation)

        # Print confirmation for each sentence processed
        print(f"Processed and saved representation for token '{row['Word']}' in sentence: '{row['Sentence']}'")

        # Clear GPU memory after each sentence
        torch.cuda.empty_cache()

    # Return all representations stored in memory
    return representations

# %%
reps={}
for key, value in deduplicated_target_items.items():

    representation=extract_bert_hidden_representations(value, output_file="representations_english.pkl", model=model, tokenizer=tokenizer)
    reps[key]=(representation)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed and saved representation for token 'planes' in sentence: 'On its journey across the Bay of Bengal the freighter was tracked by the Indian navy and Orissa - based spy planes of India 's Aviation Research Center ; it was intercepted by Indian naval vessels off Sri Lanka 's east coast .'
# Processed and saved representation for token 'grips' in sentence: 'Laser grips are the most common for wangs .'
# Processed and saved representation for token 'Words' in sentence: 'Words can be lethal .'
# Processed and saved representation for token 'minutes' in sentence: 'Of course I could n't make it back in time ( and they apparently could not stay 5 extra minutes to wait for me ) .'
# Processed and saved representation for token 'has' in sentence: 'He has encyclopedic knowledge of hundreds of different Supreme Court cases , and he can recite details from memory .'
# Processed and saved representation for token 'reasons' in sentence: 'There are many reasons to say Disney cruise is the best bet for you to have a enjoyable holiday tour .'
# Processed and saved representation for token ''s' in sentence: '" Port Blair , Havelock Islands , Diglipur , Middle Nicobar , Campbell 's Bay , Neil Islands and Rangott are mostly overrun by foreigners , " he said .'
# Processed and saved representation for token 'people' in sentence: 'lol They where super friendly towards us and treated us like people not walking bags of cash .'
# Processed and saved representation for token 'attachments' in sentence: 'If you are not the intended recipient or an authorized representative of the intended recipient , you are hereby notified that any review , dissemination or copying of this email and its attachments , if any , or the information contained herein is prohibited .'
# Processed and saved representation for token 'failures' in sentence: 'Do you have the heart to face monumental failures while bravely struggling beyond where we are now ?'
# Processed and saved representation for token 'antibiotics' in sentence: 'and will these antibiotics help ?'
# Processed and saved representation for token 'customers' in sentence: 'No business is going to push customers away without good reason ; so is n't it reasonable to think they might know what they 're doing ?'
# Processed and saved representation for token 'hours' in sentence: 'The duration of the call is 3.5 hours .'
# Processed and saved representation for token 'phones' in sentence: 'Before the phones went , I was told [ my family in Biloxi ] had lost their roof , barn , 2 oak trees and many pines and they were letting in water'
# Processed and saved representation for token 'for' in sentence: 'Attached is the TW Top Ten Shippers by Revenues for the year 2001 to be reported in the Browncover report .'
# Processed and saved representation for token 'sports' in sentence: 'The Rams , the VCU sports team , also made the NCAA Final 4 this year , too !'
# Processed and saved representation for token 'on' in sentence: 'We are following up with Sue and Robbie on a couple legal issues , case law and MSA self - certification language , and let me know if you have additional items .'
# Processed and saved representation for token 'comes' in sentence: 'I really enjoyed meeting her and happy to learn she comes from Oklahoma and has the values of a solid no bs country girl .'
# Processed and saved representation for token 'problems' in sentence: 'If you need someone to help you out with your heating problems , I DEFINITELY would call TIGER HEATING and AIR .'
# Processed and saved representation for token 'reserves' in sentence: 'By dumping some portion of their reserves , these countries could put the dollar under intense pressure and send U.S. interest rates skyrocketing .'
# Processed and saved representation for token 'materials' in sentence: 'Fresh Design Studio helped jump - start my own business by providing affordable and effective marketing materials : logo , flyers , posters ad design , and more .'
# Processed and saved representation for token 'Musharraf' in sentence: 'Musharraf held elections in October of 2002 , in which center - right parties did well , but in which nearly 20 percent of parliament seats went to the fundamentalist religious party coalition , MMA .'
# Processed and saved representation for token 'divisions' in sentence: 'With divisions , EOL does request a new Password Application for the applicant reflecting the name as you noted below .'
# Processed and saved representation for token 'points' in sentence: 'Best answer shall receive points :)'
# Processed and saved representation for token 'says' in sentence: 'Logic says no , but logic seldom plays any part in modern American politics .'
# Processed and saved representation for token 'animals' in sentence: 'These animals have the misfortune to produce a substance that is useful in the manufacture of perfume .'
# Processed and saved representation for token 'Deals' in sentence: 'The Best Deals in Town'
# Processed and saved representation for token 'alarms' in sentence: 'These are not household type alarms .'
# Processed and saved representation for token 'commitments' in sentence: 'We have already received firm commitments from 3 companies .'
# Processed and saved representation for token 'for' in sentence: 'UVB and basking temp ( should be about 110 F for a baby , 95 F for an adult ) should be available for 10 - 12 hours a day .'
# Processed and saved representation for token 'interviews' in sentence: 'Campus interviews are scheduled as follows :'
# Processed and saved representation for token 'loves' in sentence: 'She loves giraffes and homemade things !'
# Processed and saved representation for token 'stores' in sentence: 'They also have the best tea I ever had , not at all like the junk you get at the grocery stores , I stock up when ever there because they are closed in the winter .'
# Processed and saved representation for token 'pressures' in sentence: 'I was unable to say much about it in my Risk Electricity Hedging and Trading report because of deadline pressures .'
# Processed and saved representation for token 'keeps' in sentence: 'India keeps what it has while Pakistan and China ( which was gifted a slice of the territory three decades ago ) do likewise .'
# Processed and saved representation for token 'guilds' in sentence: 'It was formed to allow many different guilds who were all strictly honorable to come together as a family and allow them many people to game with .'
# Processed and saved representation for token 'issues' in sentence: 'Saying that I need to give him my address or else I have intimacy issues is not helpful .'
# Processed and saved representation for token 'increases' in sentence: 'Price increases will cause a dramatic reduction in American real incomes .'
# Processed and saved representation for token 'weapons' in sentence: 'In a statement issued June 16 , 2004 , the 9/11 Commission Staff concluded that " Al Qaeda had an ambitious biological weapons program and was making advances in its ability to produce anthrax prior to September 11 .'
# Processed and saved representation for token 'on' in sentence: 'I got a riding lesson today on one of my boss 's fino horses and it made me realize just how unsteady my left leg is .'
# Processed and saved representation for token 'agents' in sentence: '14 - Number of Immigration and Naturalisation Service ( INS ) agents assigned to track down 1,200 known illegal immigrants in the United States from countries where al - Qa'ida is active .'
# Processed and saved representation for token 'charges' in sentence: 'The charges that they have put some vets up to making against Kerry are false and can be demonstrated by the historical record to be false .'
# Processed and saved representation for token 'classes' in sentence: 'Try obedience classes .'
# Processed and saved representation for token 'snakes' in sentence: 'My wife was TERRIFIED of snakes when we first met , I introduced her to one out my baby corn snakes and she fell in love with it .'
# Processed and saved representation for token 'thanks' in sentence: 'thanks ,'
# Processed and saved representation for token 'times' in sentence: 'You have to be in command at all times .'
# Processed and saved representation for token 'arms' in sentence: 'LTTE arms - running'
# Processed and saved representation for token 'Queso' in sentence: 'Queso should not be watery :( .....'
# Processed and saved representation for token 'drugs' in sentence: 'The drugs and arms travel in all directions .'
# Processed and saved representation for token 'dogs' in sentence: 'Spongy and sweet bread ( microwaved ? ) , heartless salsa , tiny dogs ...'
# Processed and saved representation for token ''s' in sentence: 'Kumaratunga 's India tour preceded a three - day visit to Sri Lanka by Norwegian Foreign Minister Jan Petersen in a new bid to revive the peace talks that were supposed to follow a ceasefire that Oslo successfully brokered in February 2002 .'
# Processed and saved representation for token 'wolves' in sentence: 'True , there are about 300,000 wolves and wolf hybrids kept as pets in the United States .'
# Processed and saved representation for token 'troops' in sentence: 'Than the troops being issued the weapon were told it was self - cleaning , which it was n't .'
# Processed and saved representation for token 'rights' in sentence: 'Thus far , none of the many " human rights " busybodies across the world have bothered to even notice such a development .'
# Processed and saved representation for token 'contracts' in sentence: 'detailed position analysis of all OBSF contracts that must be reconciled to Barclays documentation'
# Processed and saved representation for token 'on' in sentence: 'Put on a pair of spurs and before she makes that trot step , it 's in the feeling when you feel her think trot , tick her with the spur and lift with your body to keep her moving .'
# Processed and saved representation for token 'cities' in sentence: 'From either of those cities , you can venture out and spend a day in the country .'
# Processed and saved representation for token 'folks' in sentence: 'For better or worse , all the folks under the heading " Origination " and " Development " are ours , although Kathleen has a special role with Development .'
# Processed and saved representation for token 'restaurants' in sentence: 'Service was average , but nothing special , and restaurants that are supposed to be excellent should do a better job of training their waitstaff to be communicative and friendly , not merely capable .'
# Processed and saved representation for token ''s' in sentence: 'The Chernobyl Children 's Project ( http://www.adiccp.org/home/default.asp ) offers several ways to help the children of that region .'
# Processed and saved representation for token 'papers' in sentence: 'The newly released papers , showing him complicit in the airliner bombing , were mentioned'
# Processed and saved representation for token 'for' in sentence: 'I am waiting longer at BNA for my pickups and last time I parked with them , they lost my car key .'
# Processed and saved representation for token 'services' in sentence: 'We are very concerned with providing services that are relevant to that environment .'
# Processed and saved representation for token 'drawings' in sentence: 'Nigel from Nidd Design has always provided a first class service , from his advice and professionalism to the quality of his design drawings and planning applications .'
# Processed and saved representation for token 'authorities' in sentence: 'A Sri Lanka - born Tamil with a Norwegian passport was arrested by Thai authorities in 2000 for his links with the LTTE .'
# Processed and saved representation for token 's' in sentence: 'In this day it s rare to find such wonderful people who CARE , Not the kind of want to make cash .'
# Processed and saved representation for token 'people' in sentence: 'I add that in because there have been some people who have tried to claim citizenship by sending for their birth certificate when they were never really born in Canada or to Canadian parents .'
# Processed and saved representation for token ''s' in sentence: 'And , let 's remember , flying supersonic fighter jets is dangerous !'
# Processed and saved representation for token 'for' in sentence: 'Evidently , this a problem that Stacey White has been aware of for a couple of months now .'
# Processed and saved representation for token 'for' in sentence: '" It is very dangerous for this country to condone the overthrow of democratically elected governments , " said David Leavy , spokesman for the National Security Council .'
# Processed and saved representation for token 'appropriators' in sentence: 'The committee voted to give NASA $ 16.4 billion in 2005 , about $ 200 million more than what the President requested and over $ 1 billion more than what House appropriators approved in July . "'
# Processed and saved representation for token 'resolutions' in sentence: 'The Tigers ' chief ideologue , Balasingham , sniffed at the proposal saying that " a solution to the ethnic conflict can not be predetermined by the resolutions or declarations of donor conferences , but has to be negotiated by the parties in conflict without the constraints of external forces . "'
# Processed and saved representation for token 'terms' in sentence: 'Also , would those of you who have not responded to me via email confirming your acceptance of the terms upon which our four companies have agreed to assume cost responsibility for the TCA work on this .'
# Processed and saved representation for token ''s' in sentence: 'To Paul McCartney whose company 's logo was a person toying with the planets as if he was a god , and who was being very much deluded in his ego trip by the fact that he was made " Sir " ( when in England even the road sweeper is made Sir , as long as he produces money for the nation ) , GOD provided cancer to the wife .'
# Processed and saved representation for token 'explorers' in sentence: 'President Bush has directed NASA to return to the moon by 2018 with a new generation of human explorers .'
# Processed and saved representation for token 'products' in sentence: 'When I get my hair done there , they use enough hairstyling products while it does not ruin your hair .'
# Processed and saved representation for token 'dragons' in sentence: 'Bearded dragons are sight hunters , they need to see the food move to trigger a feeding response , especially when they are babies .'
# Processed and saved representation for token 'times' in sentence: 'These are always difficult times .'
# Processed and saved representation for token 'friends' in sentence: 'my friends and I are trying to melt bras to make some little figures .'
# Processed and saved representation for token 'lines' in sentence: 'Like the previous poster said , the com lines are split between the entire building .'
# Processed and saved representation for token 'habits' in sentence: 'There are naive old - fashioned habits such as respecting religious sites and symbols , not using ambulances and hospitals for acts of war , avoiding the mutilation of dead bodies and not using children as human shields or human bombs .'
# Processed and saved representation for token 'transactions' in sentence: 'We need to include all outstanding transactions .'
# Processed and saved representation for token 'tomatos' in sentence: 'They love leaf or romaine lettuce and tomatos , celery , cucumbers , carrots .'
# Processed and saved representation for token 'vendors' in sentence: 'Since the bankruptcy filing , vendors have been very reluctant to ship material prior to it being prepaid ( Daniels , Fisher , Rosemont , other ) .'
# Processed and saved representation for token 's' in sentence: 'It s Really Good And The Rat Calculater Says Is Big Enough For 5 Rats , But I Would Put A Maximum Of 4 In It Really :)'
# Processed and saved representation for token 'sources' in sentence: 'According to a couple sources , the world record for the oldest cat was a cat in Devon , England who reportedly live to the age of 36 .'
# Processed and saved representation for token 'areas' in sentence: 'if there are shady areas he can move to ( for example a 3 x 5 x 4 tank with light on one side ) then you can leave it on a full 12 - 14 hours , if it s a small tank and he ca n't escape the light then 4 - 6 at most at a time though quite possibly 4 - 6 hours at a time twice a day .'
# Processed and saved representation for token 'sensors' in sentence: 'There should be a Pixel Mapping function in the menu that will get rid of them , most sensors have a few dead and flipped pixels , some only show up on long exposures .'
# Processed and saved representation for token 'days' in sentence: '28 - Number of vacation days Bush took in August 2001 , the month he received a 6 August Presidential Daily Briefing headed " Osama bin Laden Determined to Strike US Targets . "'
# Processed and saved representation for token 'flowers' in sentence: 'The flowers were all that I hoped they would be , I have attended several funerals of late unfortunately and the flowers I recieved from Ana outshone them all .'
# Processed and saved representation for token 'shirtsleeves' in sentence: 'It may be shirtsleeves and sunglasses in February , but winter woollies in March and even during the summer .'
# Processed and saved representation for token 'sessions' in sentence: 'The sessions were nice and I felt relaxed after them but did not notice any changes with my cycles .'
# Processed and saved representation for token 'times' in sentence: 'At times , the pressure on your job and home life may seem unbearable , but rest assured you will come through this stronger - and wiser - than ever , as more is revealed and resolved in 2005 .'
# Processed and saved representation for token 'temples' in sentence: 'Over nine dozen temples that had served the Hindu population have been destroyed , with some used as building material and others as urinals .'
# Processed and saved representation for token 'Hens' in sentence: 'Hens make excellent mothers as they are bigger , can see better , and are smarter the Silkies .'
# Processed and saved representation for token 'dates' in sentence: 'He kept saying different arrival / delivery dates and did n't seem terribly apologetic .'
# Processed and saved representation for token 'Walls' in sentence: 'Walls keeping water out of the bowl - shaped city have been breached , and emergency teams are using helicopters to drop 1,350 kg ( 3,000 lb ) sandbags and concrete barriers into the gaps .'
# Processed and saved representation for token 'elections' in sentence: 'If democracy is just free elections , it is likely that the most fanatic regime will be elected , the one whose incitement and fabrications are the most inflammatory .'
# Processed and saved representation for token 'insights' in sentence: 'You need our insights just as we need your structure .'
# Processed and saved representation for token 'COSTS' in sentence: 'AVOID AT ALL COSTS .'
# Processed and saved representation for token 'goals' in sentence: 'Anything you could do to help further my goals would be appreciated .'
# Processed and saved representation for token 'on' in sentence: 'My perspective is entirely based on what I see , on what I read and on the fact that my family has lived in this region for almost 200 years .'
# Processed and saved representation for token 'islands' in sentence: 'Considering the islands ' huge strategic importance , it is amazing how lax New Delhi has been .'
# Processed and saved representation for token 'Copies' in sentence: 'Copies will be distributed .'
# Processed and saved representation for token ''s' in sentence: 'Here 's the list with the missing counterparties .'
# Processed and saved representation for token 'days' in sentence: 'For $ 56 you can even have it expedited and will get in three business days or your money back .'
# Processed and saved representation for token 'experiences' in sentence: 'Allen Tire was recommended by friend after my having bad tire experiences in Temecula .'
# Processed and saved representation for token 'pictures' in sentence: 'She gave me amazing pictures at an amazing price and made my wedding day so memorable .'
# Processed and saved representation for token ''s' in sentence: 'Bottom line is that when it 's a small privatly owned resturant like this is you can tell that the owners and employees take pride in their product and service .'
# Processed and saved representation for token 'details' in sentence: 'Many details remain to be worked out , but we will keep you advised .'
# Processed and saved representation for token 'for' in sentence: 'She asked for the dinner combo and they gave her two dinner plates instead .'
# Processed and saved representation for token 'days' in sentence: '13 - Number of vacation days the average American receives each Year .'
# Processed and saved representation for token 'on' in sentence: 'In addition , from my understanding one - on - one dates is something that comes much later and not ' straight - away ' like us anglo - saxons .'
# Processed and saved representation for token 'fundamentalists' in sentence: 'Sunni Arab fundamentalists deeply sympathize with the Palestinians and with Hamas , and those in Iraq have deep historical inks with fundamentalists in Jordan and Palestine .'
# Processed and saved representation for token 'percentages' in sentence: 'By Friday December 1st , could you please tell me the percentages / amount of time you spent on East Coast Power during the months of October and November .'
# Processed and saved representation for token 'Publications' in sentence: 'Publications are available on request .'
# Processed and saved representation for token 'spikes' in sentence: 'bit of a stupid question but do the spikes / spines ( whatever you call them ) on their side and face area ever go hard .'
# Processed and saved representation for token 'on' in sentence: 'You do have to give NASA credit on some things as they have eliminated the " fear of reporting failure " culture that probably led to the lack of reporting defects on the Columbia shuttle .'
# Processed and saved representation for token 'lawyers' in sentence: 'In BA , I 'll be meeting with Marval lawyers .'
# Processed and saved representation for token 'for' in sentence: 'Most of us still have hope for ourselves even when stuck in the darkest dilemmas , ruts and catch - 22s .'
# Processed and saved representation for token 'for' in sentence: 'Thank you for your patience and I hope you can take a few moments to enjoy the holidays .'
# Processed and saved representation for token 'on' in sentence: 'In Fall 2004 , MSNBC , relying on an unnamed FBI spokesperson , reports that the FBI has narrowed the pool of labs known to have had Ames that was a match from 16 to 4 but can not rule out that it was made overseas .'
# Processed and saved representation for token 'girls' in sentence: 'I think just living in a house with so many girls is making him go crazy ?'
# Processed and saved representation for token 'remembers' in sentence: 'EDIT : My memory may not be good so you might get a more accurate answer from someone else who remembers the time .'
# Processed and saved representation for token 'colors' in sentence: 'They are adorable they have beautiful colors and personality .'
# Processed and saved representation for token 'citizens' in sentence: 'The mass murder happening right now in Sudan , where the Arab Moslem regime is massacring its black Christian citizens , has nothing to do with Israel .'
# Processed and saved representation for token 'Thanks' in sentence: 'Thanks for your help this morning .'
# Processed and saved representation for token ''s' in sentence: 'Note that this communication is confidential , covered by CA 's settlement rules .'
# Processed and saved representation for token 'Lots' in sentence: 'Lots of rules , phantom innkeeper , last minute price was worth it .'
# Processed and saved representation for token 'deals' in sentence: 'Because they cut me good deals if I paid in cash .'
# Processed and saved representation for token 'families' in sentence: 'In the meanwhile there are still broken families that should have been safe in the home of the brave .'
# Processed and saved representation for token 'things' in sentence: 'There are so many things to do that you will only use your room for sleeping and the extra cost of the balcony is wasted .'
# Processed and saved representation for token 'intends' in sentence: 'Everybody I know at university intends to stay at uni for as long as possible until there are actually jobs available .'
# Processed and saved representation for token 'on' in sentence: 'The price of crude oil on the international market hit a record $ 70.85 a barrel due to the vulnerability of oil and gas fields in the Gulf of Mexico .'
# Processed and saved representation for token 'x' in sentence: 'They did nt take x - rays they offered them but i just could nt afford any more treatment .'
# Processed and saved representation for token 'for' in sentence: 'A revised version of the Evaluation form for Associates and Analysts is attached below .'
# Processed and saved representation for token 'Budgies' in sentence: 'Budgies are breast feeding birds and it may be the male is bisexual .'
# Processed and saved representation for token 'on' in sentence: 'It put hair on my chest and thanks to the owner s advice I invested vanguard , got myself a woman like Jerry , and became a republican .'
# Processed and saved representation for token 'stripes' in sentence: 'the stripes are like hair the less stipes the older .'
# Processed and saved representation for token 'animals' in sentence: 'I will never go to another vet as long as I have animals .'
# Processed and saved representation for token 'regrets' in sentence: 'I have to decline the invitation with regrets .'
# Processed and saved representation for token 'contacts' in sentence: 'If you can pass this info along , and ask everyone you know to forward it to their contacts , etc , we may have a shot at pulling this off .'
# Processed and saved representation for token 'means' in sentence: 'Al Qaeda had both the means and opportunity .'
# Processed and saved representation for token 'for' in sentence: 'I had been a patient of Dr. Olbina for 9 years and had spent thousands of dollars on crowns etc .'
# Processed and saved representation for token 'Visualisations' in sentence: 'Visualisations can be as useful tools , but meditation is more than that .'
# Processed and saved representation for token 'things' in sentence: 'I need 2 things from you .'
# Processed and saved representation for token 'fingers' in sentence: 'Remove your fingers from the existing grip and replace them with your new laser grip .'
# Processed and saved representation for token 'restaurants' in sentence: 'Yo also may want to try " small neighborhood " restaurants and support family run places rather than the large corporate chains .'
# Processed and saved representation for token 'bowls' in sentence: 'you will need to get his box and bowls , and whatever blanket and toys are his , and smell like home , and put him in a room .'
# Processed and saved representation for token 'humans' in sentence: 'Blue Planet is a weekly series examining the relationship of humans to the environment , by veteran environmental reporter Dan Whipple .'
# Processed and saved representation for token 'times' in sentence: 'It is interesting to notice that he was shot seven times , being seven , as well as three , the holy numbers in Holy Cabalah tradition ....'
# Processed and saved representation for token 'cancers' in sentence: 'The dramatic increase in radiation - induced thyroid cancers in children and adolescents in Belarus , Russia , and Ukraine , which have been observed since 1991 , continues to this day .'
# Processed and saved representation for token 'works' in sentence: 'I seem to remember something about ' by their works shall ye know them . "'
# Processed and saved representation for token 'for' in sentence: 'So , as I was leaving I asked for the designer / dress name or style number associated with my top picks .'
# Processed and saved representation for token 'comments' in sentence: 'Attached are an original and blacklined copy of your form of guaranty , which reflect our comments .'
# Processed and saved representation for token 'takes' in sentence: 'it usually takes 20 mins for a mezza luna , as they have to add pure delicious extract to the mix .'
# Processed and saved representation for token 'miles' in sentence: 'Had 33,000 miles , Ram 2500 3 / 4 ton , 4 x 4 , 360 Magnum Motor .'
# Processed and saved representation for token 'for' in sentence: 'Then one day , Ahmed left the country , not to return for months , WITHOUT informing me .'
# Processed and saved representation for token 'rates' in sentence: '$ 10.0 m - negotiated rates reserve ( Reliant , Sempra , Richardson , Astr , and BP Energy ) - $ collected'
# Processed and saved representation for token 'losses' in sentence: 'Tet made it clear that the war was a long way from being over if the Americans thought they could preserve the South and that the North was perfectly willing to suffer great losses to continue their fight .'
# Processed and saved representation for token 'days' in sentence: 'I would actually send them the draft Development Agreement a couple days after the LOI .'
# Processed and saved representation for token 'on' in sentence: 'Nina Leopold Bradley , a plant ecologist and daughter of the conservation pioneer Aldo Leopold , published a 1999 paper in the Proceedings of the National Academy of Sciences on her 61 - year uninterrupted phenological records .'
# Processed and saved representation for token 'data' in sentence: 'China we have current data already'
# Processed and saved representation for token 'nights' in sentence: 'seriously , can you imagine having to live through these last few nights without heat ?'
# Processed and saved representation for token 'into' in sentence: 'This trickle grew into a flood , resulting in 14 wolves being reintroduced in Yellowstone in 1995 by the U.S. Fish and Wildlife Service -- albeit over the strong and still - continuing objections of ranchers .'
# Processed and saved representation for token 'conferees' in sentence: 'That India is not Yugoslavia and that the " foreigner - led " Indian National Congress can least afford to ignore Indian nationalism , has not struck the conferees , among whom have been several Indian " scholars " and " analysts " ready to say and endorse anything for the sake of a free trip to New York or Vienna .'
# Processed and saved representation for token 'holdings' in sentence: 'It has never properly declared its holdings of chemical weapons , and the status of its biological weapons programs is unknown . "'
# Processed and saved representation for token 'clothes' in sentence: 'The thing to do is to bring the right clothing with you , clothes so you can layer up if it is cold and take off layers when it warms up .'
# Processed and saved representation for token 'books' in sentence: 'only in comic books and sci - fi tv shows / movies ... :D'
# Processed and saved representation for token 'works' in sentence: 'Suerat ( any works on paper ? -'
# Processed and saved representation for token 'for' in sentence: 'We are planning this event for Thursday , February 15 and are inviting approximately 30 candidates to be interviewed .'
# Processed and saved representation for token 'steps' in sentence: 'Keep a copy of these steps for yourself and whenever you need money , you can use it again , and again .'
# Processed and saved representation for token 'taxes' in sentence: 'Argentina intend to press ahead even given the concern about taxes , etc .'
# Processed and saved representation for token 'courses' in sentence: 'George W. Bush and his administration have consistently undertaken incredibly dangerous courses of action in order to garner political power on the home front .'
# Processed and saved representation for token 'individuals' in sentence: 'You are individuals of quality , and in our alliance we seek quality of member over quantity of member .'
# Processed and saved representation for token 'lots' in sentence: 'Since lots of people are still living there , then it must be fine to visit .'
# Processed and saved representation for token 'seems' in sentence: 'I know it seems like a stretch , but the market for hourly traders is very strong right now .'
# Processed and saved representation for token 'confirms' in sentence: 'Confirmation Desk : you can stop adding the rep to the confirms now .'
# Processed and saved representation for token 'payers' in sentence: 'of course , in a perfect world , tax payers ' money would go toward some sort of national healthcare program , and housing for the homeless , but this is far from a perfect world .'
# Processed and saved representation for token 'secretaries' in sentence: 'While most U.S. secretaries of state -- save perhaps Dean Rusk -- have gobbled up credit for outcomes that they had little to do with , few have been as brazen as Colin Powell .'
# Processed and saved representation for token 'envelopes' in sentence: 'They were sent to our second room and had been opened -- the ribbon - wrapped present , and all 3 envelopes .'
# Processed and saved representation for token 'allies' in sentence: '" The Bush administration is preparing its NATO allies for a possible military strike against suspected nuclear sites in Iran in the New Year , according to German media reports , reinforcing similar earlier suggestions in the Turkish media , " reported UPI on December 30th .'
# Processed and saved representation for token 'eggs' in sentence: 'Ironically sometimes it is wise to leave the newly picked eggs in fresh tap water with some chlorination to kill microscopic critters that ride in with the eggs .'
# Processed and saved representation for token 'finches' in sentence: 'I ended up getting a pair of zebra finches for christmas .'
# Processed and saved representation for token 'for' in sentence: '$ 59,339 - Amount the Bush campaign reimbursed Enron for 14 trips on its corporate jet during the 2000 campaign .'
# Processed and saved representation for token 'for' in sentence: 'Afshari , who was posted in Germany and was responsible for receiving Mujahedeen children during the gulf war , said that when the German government tried to absorb Mujahedeen children into their education system , the Mujahedeen refused .'
# Processed and saved representation for token 'reminds' in sentence: 'It reminds me too much of the ARVN officers who were secretly working for the other side in Vietnam .'
# Processed and saved representation for token 'rates' in sentence: 'They have the best rates and GREAT customer service .'
# Processed and saved representation for token ''s' in sentence: 'The Commission 's hearings begin tomorrow at 10 AM ( PST ) .'
# Processed and saved representation for token 'experts' in sentence: 'Most experts believe China intends to develop a small space station of its own over the next several years .'
# Processed and saved representation for token 'Beardies' in sentence: 'Beardies are actually quite delicate .'
# Processed and saved representation for token 'for' in sentence: 'i was looking for a car but did not really know what i wanted and they were very helpful and took the time to first figure out what my needs were and showing me various options to meet those needs .'
# Processed and saved representation for token 'universities' in sentence: 'They 'll give you a comprehensive list of all the universities that do the courses you want , plus all the information you need to apply .'
# Processed and saved representation for token 'anticipates' in sentence: 'PG&E also anticipates that the Core Procurement Incentive Mechanism ( CPIM ) will be similar to today 's mechanism , but will reflect the somewhat larger capacity holdings needed to meet anticipated increases in core demand and to meet a 1 - day in 10 - year cold weather event .'
# Processed and saved representation for token ''s' in sentence: 'China 's insatiable demand for energy is prompting fears of financial and diplomatic collisions around the globe as it seeks reliable supplies of oil from as far away as Brazil and Sudan .'
# Processed and saved representation for token 'authorities' in sentence: 'Wherever he is , authorities need to focus on the traceable connection between him and those he or Atef recruited .'
# Processed and saved representation for token 'advantages' in sentence: 'Pursuing a successful career , along with the usual social and financial advantages , will be easier this year than it has in a long time for you , Leo !'
# Processed and saved representation for token 'for' in sentence: 'We lived here for 2 years , the first year or so was okay .'
# Processed and saved representation for token 'for' in sentence: 'I do n't know if the kid had a bad day or what , but I had to sit and apologize about nothing for 10 minutes until he dropped the issue .'
# Processed and saved representation for token 'people' in sentence: '" The black race is the people through which the devil has always been able to bring evil unto the earth , " Jeffs has said as cited by the Southern Poverty Law Center 's " Intelligence Report . "'
# Processed and saved representation for token 'people' in sentence: 'The husband and wife who run this spot are lovely people .'
# Processed and saved representation for token 'gates' in sentence: 'or do i just show them passport and walk through the gates ?'
# Processed and saved representation for token 'weeks' in sentence: 'Six weeks of basic training .'
# Processed and saved representation for token ''s' in sentence: 'It was Mr. Bush 's job to organize the Republican county chairpersons in the 67 Alabama counties .'
# Processed and saved representation for token 'days' in sentence: 'If they do n't like it , it 'll only be two days , remember ?'
# Processed and saved representation for token 'stores' in sentence: 'Look in the pet stores for " fry food " or " baby fish foods " .'
# Processed and saved representation for token 'points' in sentence: 'Can i apply with 63 points ?'
# Processed and saved representation for token 'for' in sentence: 'I moved to Creekside Apartments in August 2008 with a 6 - month lease and have just extended it for another 13 months !'
# Processed and saved representation for token 'funds' in sentence: 'She does n't have the funds to continue without the grant , and without these treatments , her prognosis is grim .'
# Processed and saved representation for token 'cells' in sentence: 'On sensing my incredulity to his statement he asserted that Ba'athist cells exist in all parts of the country and that they do have a central command , even though many have formed seperate cells ( often under Islamic labels ) with their own leaderships .'
# Processed and saved representation for token 'believes' in sentence: 'Dunn believes the resulting overcharges for electricity exceeded $ 30 billion .'
# Processed and saved representation for token 'comments' in sentence: 'We look forward to hearing your comments .'
# Processed and saved representation for token 'Regards' in sentence: 'Regards ,'
# Processed and saved representation for token 'Voters' in sentence: 'Voters are perfectly able to decide whether it ’s important or not in November .'
# Processed and saved representation for token 'soldiers' in sentence: 'Of course , the sooner the US soldiers can be withdrawn in favor of less - provocative local or international forces , the better .'
# Processed and saved representation for token ''s' in sentence: 'That is the source of Tana 's concern regarding the correct entering of divisions in the system .'
# Processed and saved representation for token 'people' in sentence: 'We had fewer people running across the Mexican border then .'
# Processed and saved representation for token 'on' in sentence: 'They will be there by noon on the 20th , and the surgery will last 1.5 hours and then they 'll watch him for 2 more hours before they put him into ICU .'
# Processed and saved representation for token 'people' in sentence: 'It was Joseph Goebbels who said that if you repeat a lie often enough , people will believe it .'
# Processed and saved representation for token 'bozos' in sentence: 'The freaky thing here is that these bozos are seriously claiming the moral high ground ? ? ? ? ?'
# Processed and saved representation for token 'tires' in sentence: 'Also they will fill your tires with air and other small maintenance tasks for free , even if you did n't buy your car there !'
# Processed and saved representation for token 'workers' in sentence: 'Bait and switch , untrained workers'
# Processed and saved representation for token 'folks' in sentence: 'I do n't believe that folks who believe that America is the land of opportunity will change their views from this recent news .'
# Processed and saved representation for token 'needs' in sentence: 'He needs more info about these trades ( i.e. , price info ) and would like to talk with you about it .'
# Processed and saved representation for token 'for' in sentence: 'This rail is used for multi purposes , such as laser devices or flashlight devices .'
# Processed and saved representation for token 'speaks' in sentence: 'The history of alcoholism and possibly other drug use is a key issue because it not only speaks to Bush 's character as an addictive personality , but may tell us something about his erratic and alarming actions as president .'
# Processed and saved representation for token 'laws' in sentence: 'When you go to another country , you live by their way of life and their laws , if you do n't like it , you know how to get back out the country ( but I guess our benefits system is too much to throw away , huh ) .'
# Processed and saved representation for token 'sights' in sentence: 'While they are extremely accurate , laser sights do not operate well when drunk or high because the beam often does not show up on the target .'
# Processed and saved representation for token 'others' in sentence: 'If you were of integrity , the program will continue and the money that so many others have received will come your way .'
# Processed and saved representation for token 'people' in sentence: 'You can fool people'
# Processed and saved representation for token 'places' in sentence: 'I just moved nearby and have tried several of the local places , this was the first one and I should have just stuck with it .'
# Processed and saved representation for token 'markets' in sentence: 'At some point , I 'd like to talk about the diversification strategy in more detail -- perhaps over dinner or a quick meeting after the markets close ?'
# Processed and saved representation for token 'officers' in sentence: 'Some 2,000 junior officers of the old Baath army have been recalled to duty in recent months , something Chalabi would have blocked if he could have .'
# Processed and saved representation for token 'people' in sentence: 'He responded " we have problem with ' people ' " .'
# Processed and saved representation for token 'years' in sentence: 'By the time it was over , Bush had served nearly two years .'
# Processed and saved representation for token 'on' in sentence: 'Travelling on your own you would have to pay double as cabins are sold on the basis of double occupancy .'
# Processed and saved representation for token 'postcards' in sentence: 'I ordered 1000 postcards , we normally order 5000 or more .'
# Processed and saved representation for token 'pictures' in sentence: 'Well , T.V. is a series of flickering pictures that are streamed together to make a moving picture .'
# Processed and saved representation for token 'vendors' in sentence: 'Disatisfied customer , I went through Kitchen Aid and used one of their recommended vendors .'
# Processed and saved representation for token 'Police' in sentence: 'Police said Bernard confessed to detectives that he had sex with a young girl in November 2002 and admitted to knowing about sexual acts involving children and a dog that occurred at Hosanna Church .'
# Processed and saved representation for token 'Thanks' in sentence: 'Thanks Dan and Johnette for your responsiveness and professional service .'
# Processed and saved representation for token 'myths' in sentence: 'One of the most widespread myths of recent times is that the Chernobyl nuclear reactor accident in 1986 caused many thousands of extra cancer deaths in neighbouring regions , and that public health has been severely affected by exposure to radiation .'
# Processed and saved representation for token 'for' in sentence: 'Sometimes you can make a bad decision very quickly , then regret it for many years to come .'
# Processed and saved representation for token 'leads' in sentence: 'Marriage is , in and of itself , a noble concept , but it too often leads to kids and kids flat out suck .'
# Processed and saved representation for token 'fields' in sentence: 'I felt like I was in heaven when I walked through the majestic fields of this particular farm .'
# Processed and saved representation for token ''s' in sentence: 'But even before the incident the People 's Daily , the government mouthpiece , had commented that competition over the East China Sea between the two countries was " only a prelude of the game between China and Japan in the arena of international energy " .'
# Processed and saved representation for token 'instructions' in sentence: 'On a certain evening , which had been prearranged , I sent my friend final instructions , for the man was forever on the alert and continually changed his room .'
# Processed and saved representation for token ''s' in sentence: 'Paul was going out with Heather , but in front of the audience he played the faithful husband 's masquerade pretending to suffer for Linda , for the afore mentioned promotional ends .'
# Processed and saved representation for token 'women' in sentence: 'Instead , they send outcast women , naive children , retarded people and young incited hotheads .'
# Processed and saved representation for token 'groups' in sentence: 'Small polygamous groups have existed in the southwestern US under the watchful yet fairly benign eye of authorities ever since a sect known as the Fundamentalist Latter Day Saints ( FLDS ) separated itself from mainstream Mormonism in 1890 .'
# Processed and saved representation for token 'things' in sentence: 'I called her grandmother and explained things to her .'
# Processed and saved representation for token 'comes' in sentence: 'well if your desired boarding station comes after more than 2 or 3 halts of the actual boarding point , then the TC will cancel you ticket and allot the seat to others .'
# Processed and saved representation for token 'items' in sentence: 'Security in the hotel seemed to be excellent , but we were never given an explanation as to why someone would open these items .'
# Processed and saved representation for token 'rounds' in sentence: 'Colombo held six rounds of talks with the Tigers between September 2002 and March 2003 .'
# Processed and saved representation for token 'times' in sentence: 'I have been here a few times for oil changes and just got my tires , alignment and state inspection done yesterday .'
# Processed and saved representation for token 'restrictions' in sentence: 'In late September 2001 , it was announced that the President was seeking a blanket waiver that would lift all restrictions on aid to military and security units in connection with pursuing the militant islamists .'
# Processed and saved representation for token 'tables' in sentence: 'Half the tables and bar were empty by this point .'
# Processed and saved representation for token 'conversations' in sentence: 'Doug and I met with the Chairman of PUCT and have had subsequent conversations .'
# ...
# Processed and saved representation for token 'on' in sentence: 'I suggest a " blind draw " on the teams , best ball not scramble on the golf , and as for the wager , no emails from the losing team for one week !'
# Processed and saved representation for token 'for' in sentence: 'We were told by a detective and asked to check our credit for anything unusual .'
# Processed and saved representation for token 'for' in sentence: 'Free of polution , free of oil dependency , and free of big business that is bleeding us dry for the short term good ( theirs ) .'
# Processed and saved representation for token 'reservations' in sentence: 'Beth has made our reservations for the Round Table Friday night ( 5/18 ) at Sullivan 's Steak House for 6:30 .'
# Processed and saved representation for token 'people' in sentence: 'I read of a case not long ago when some people were trying to get a polygamous judge taken off the bench for not obeying state law .'
# Processed and saved representation for token 'for' in sentence: 'extend the time he is out each day , but for the first month , always put him in his room at night , so he feels safe to sleep .'
# Processed and saved representation for token 'for' in sentence: 'I personally have had wonderful service and if you re truely looking for a FAMILY practice ... Warner Family is the place for you .'
# Processed and saved representation for token 'goes' in sentence: 'This Friday - Michael goes for a visit at St. Francis , which may be his new school ( so far , so good ) .'
# Processed and saved representation for token 'for' in sentence: 'We have attended A Ward Dance Centre for over a year and really enjoy the friendly and welcoming way we are taught Ballroom and Latin as well as the fun filled social dance evening held every Saturday evening ....'
# Processed and saved representation for token 'wrinkles' in sentence: 'Despite many wrinkles , India remains a part - democracy and merely signing on to a piece of paper that calls for an independent Kashmir does not get you into the trouble that writing an op - ed piece against Sonia Gandhi or Atal Behari Vajpayee would instantly .'
# Processed and saved representation for token 'for' in sentence: 'It is a dance for both males and females .'
# Processed and saved representation for token 'for' in sentence: 'Then one day , Ahmed left the country , not to return for months , WITHOUT informing me .'
# Processed and saved representation for token 'Hotels' in sentence: 'Hotels for travelling will be expensive .'
# Processed and saved representation for token 'for' in sentence: 'Go onto the UCAS website , go onto course search and search for the courses you want to do .'
# Processed and saved representation for token 'connections' in sentence: 'They are dependable , have great connections in the community , and are a great resource for finding a job .'
# Processed and saved representation for token 'for' in sentence: 'This was ( another ) nice deal for Enron .'
# Processed and saved representation for token 'for' in sentence: 'Suppose , for the sake of discussion , that someone would openly stay in a well - known address in Teheran , hosted by the Iranian Government and financed by it , executing one atrocity after another in Spain or in France , killing hundreds of innocent people , accepting responsibility for the crimes , promising in public TV interviews to do more of the same , while the Government of Iran issues public condemnations of his acts but continues to host him , invite him to official functions and treat him as a great dignitary .'
# Processed and saved representation for token ''s' in sentence: 'It 's " tall " being it 's bigger than a pony , but it 's on the small end for a horse .'
# Processed and saved representation for token 'children' in sentence: 'We have a similar case unravelling up here in the northwest with a murder of a family and missing children taken for some purpose .'
# Processed and saved representation for token ''s' in sentence: 'I highly recommend Fraiser 's for anyone planning a special event for friends , family or business .'
# Processed and saved representation for token 'forces' in sentence: 'A coalition forces spokesman confirmed they had not received " any weapons from Bosnia " and added they were " not aware of any purchases for Iraq from Bosnia " .'
# Processed and saved representation for token 'for' in sentence: 'The company has developed a unique and innovative delivery mechanism for nutritional products .'
# Processed and saved representation for token 'recommends' in sentence: 'If you want a doctor who will lie to you and say he will operate and then change his mind , and not know what he is talking about when he recommends procedures at other hospitals and says they are what you need , when they will not work for you , go to this doctor ... he is the one for you .'
# Processed and saved representation for token 'on' in sentence: 'following up on our discussion yesterday ; for these types of deals , i do nt think it s necessary to have all the documentation of our counterparty 's authorization to enter into the agreement .'
# Processed and saved representation for token 'on' in sentence: 'According to a post she made on the internet , Aafia Siddiqui expressed the same sentiment in connection with US appropriations sought in exchange for the extradition of WTC 1993 plotter Ramzi Yousef from Pakistan .'
# Processed and saved representation for token 'attorneys' in sentence: 'Cullen and Dykman ( attorneys for Boston Gas Company ) approved all of our changes on the agreement to release the Tenn and Iroq space back to Boston Gas .'
# Processed and saved representation for token 'into' in sentence: 'A little birdie told me that you were checking into tickets for Seoul .'
# Processed and saved representation for token 'herpes' in sentence: 'If you 're a fan of herpes , being ripped off , and child molesters , this is the garage for you .'
# Processed and saved representation for token 'windows' in sentence: 'Their worker even cleaned 3 of my windows and changed a lightbulb for me .'
# Processed and saved representation for token 'for' in sentence: 'We 're gearing up for our 2001 / 02 recruiting campaign and we think your experience will help us define what works best and what can be improved in our process .'
# Processed and saved representation for token 'for' in sentence: 'Even for those who later abstain , " visual - spatial abilities , abstraction , problem solving , and short - term memory , are the slowest to recover . "'
# Processed and saved representation for token 'stores' in sentence: 'Look in the pet stores for " fry food " or " baby fish foods " .'
# Processed and saved representation for token 'cats' in sentence: 'Indoor cats that are well cared for typically live 11 - 15 years .'
# Processed and saved representation for token 'for' in sentence: 'And the Moldovan airline used to transport the shipment was blasted by the UN in 2003 for smuggling arms to Liberia , human rights group Amnesty has discovered .'
# Processed and saved representation for token 'for' in sentence: 'The chlorine and ammonia ( choramine ) are not good for the eggs .'
# Processed and saved representation for token 'for' in sentence: 'TO Stay in Agra - Hotel Atithi and Aditya Palace is perfect for you .'
# Processed and saved representation for token 'for' in sentence: 'It is next to Gare du Nord and a five minute walk to Sacre Coeur which is excellent for shopping .'
# Processed and saved representation for token 'for' in sentence: 'Tet was a huge military and political disaster for the Communists .'
# Processed and saved representation for token 'for' in sentence: 'not only is this place too expensive for what it is , it s horrible !'
# Processed and saved representation for token 'for' in sentence: 'If so , I 'll get it signed by Craig Breslau today , then bring it to you for countersignature .'
# Processed and saved representation for token 'things' in sentence: 'I ca n't say enough good things about Karla and the wonderful things she has done for me and my dog Gracee .'
# Processed and saved representation for token 'has' in sentence: 'Dave is a patient and methodical teacher , who has a great ear and sensitivity for his students ' passion and the direction they want their lessons to take .'
# Processed and saved representation for token 'for' in sentence: 'We had a pretty good idea when we signed the contract that ECS would not be able to complete that by the contract start date , so we negotiated a fall back plan under which ECS is obligated to " assist [ Transwestern ] in developing a manual system to accomplish the same result and will hold harmless and keep [ Transwestern ] whole for all cost and expenses " associated with the manual system .'
# Processed and saved representation for token 'on' in sentence: 'Jane , on deal 763736 for May 01 sales to Southwest Gas , we have a pricing discrepancy .'
# Processed and saved representation for token 'for' in sentence: 'He tried to tell me it was when I told asked him if he knew what fps stood for and he had no clue .'
# Processed and saved representation for token 'for' in sentence: 'will only be in Ho chi Minh for 4 days and I am looking for a 1 day or 2 day trip to Mekong delta .'
# Processed and saved representation for token 'things' in sentence: 'As much fun as they are , I figured we would probably do some different things than what you have planned for them .'
# Processed and saved representation for token 'for' in sentence: 'The wikipedia entry for Aerocom is just a stub .. waiting for someone to put some information into it ....'
# Processed and saved representation for token 'employees' in sentence: 'Of course , they could n't call him either to ask about it because apparently they do n't keep their employees ' phone numbers ( riiight ) , so I would have to return on Monday ( driving for 3 days now with no wheel lock should I get a flat ) .'
# Processed and saved representation for token 'for' in sentence: 'I will deliver it to you for your approval .'
# Processed and saved representation for token 'for' in sentence: 'However , he left my horse without a shoe for TWO WEEKS ( now that 's what I call a crap farrier ) .'
# Processed and saved representation for token 'for' in sentence: 'If so go for it and I 'll give you all the moral support I can as you figure out what is up .'
# Processed and saved representation for token 'for' in sentence: 'Many Iraqis , including conservative and religious Iraqis , are surprisingly rooting for the Iraqi Communist party , probably in an attempt to counter the influence of Islamists in the forthcoming National Assembly .'
# Processed and saved representation for token 'for' in sentence: 'So far what they have done together has been good for us and that ’s how we would like to keep it ’’ , says Karzai .'
# Processed and saved representation for token 'for' in sentence: 'if you do n't mind being robbed , cheated or lied to then this is the company for you .'
# Processed and saved representation for token 'into' in sentence: 'That private wealth can easily be funneled into aid for the Palestinians and for Lebanese Shiites .'
# Processed and saved representation for token 'responsibilities' in sentence: 'I chose the later , but approached the front desk about the hotel policy to push over their responsibilities on local authorities , not to mention the good night s sleep i paid for but did nt get .'
# Processed and saved representation for token 'for' in sentence: 'As for me , well , I lead the simple life , own a little house in West University , own a little car ( I had to buy a new one recently - the 14 - year old 380 SE started scaring me a bit ) , you know , the usual .'
# Processed and saved representation for token 'guidelines' in sentence: 'I am forwarding to you guidelines prepared for global products trading .'
# Processed and saved representation for token 'for' in sentence: 'The program has been a postive experience for my children .'
# Processed and saved representation for token 'for' in sentence: 'I am taking my wife out for our first year wedding anniversary and we both agree that we want a good steak .'
# Processed and saved representation for token 'for' in sentence: 'Hi , I am a dog trainer for 25 yrs .'
# Processed and saved representation for token 'for' in sentence: 'Wilson was claiming that he had been working for the CIA when he sold the C - 4 to Quaddaffi .'
# Processed and saved representation for token 'skills' in sentence: 'As most of them have few technical skills , and the Andamans have little demand for them in any case , they turn to smuggling and other unlawful activities .'
# Processed and saved representation for token 'penalties' in sentence: '34 - Percentage decline in criminal penalties for environmental crimes since Bush took office .'
# Processed and saved representation for token 'for' in sentence: 'The Andaman Sea is a major conduit for this traffic , and the 572 large and small islands that constitute the Andaman and Nicobar group are a natural transit base .'
# Processed and saved representation for token 'Provides' in sentence: '* Provides for vintaged Redwood path rates for core customers . *'
# Processed and saved representation for token 'for' in sentence: 'Just do n't take it for granted - you still need to be cautious this year .'
# Processed and saved representation for token 'for' in sentence: 'I have been a friend and customer of Signs of Saltford for well over 12 years now and I also became their website supplier some 3 years ago .'
# Processed and saved representation for token 'bulbs' in sentence: 'Any white light emitting light source will emit UVA , including heat bulbs , that 's the easy one to provide for .'
# Processed and saved representation for token 'Thanks' in sentence: 'Thanks for following up on this .'
# Processed and saved representation for token 'states' in sentence: 'In part because of that reputation , the gray wolf was nearly exterminated from the lower 48 states by the 1920s , except for a small remnant population on Isle Royale National Park in Michigan 's Lake Superior .'
# Processed and saved representation for token 'for' in sentence: 'You also do n't want it getting too warm for him too often .'
# Processed and saved representation for token 'for' in sentence: 'Then I got a bill for $ 483.00 .'
# Processed and saved representation for token 'on' in sentence: 'The hearing is focused on the pilot and we have an opportunity to provide some probing questions for Wolens to direct to Sam and Tom .'
# Processed and saved representation for token 'for' in sentence: 'It also came with free balance and rotation for the life of the tires !'
# Processed and saved representation for token 'dogs' in sentence: 'My dogs are far from perfect , and one of them I believe would be a little much for daycare here herself ( at least initially ) .'
# Processed and saved representation for token 'states' in sentence: 'According to the Citizenship and Immigration Canada web site at http://www.cic.gc.ca/english/immigrate/skilled/assess/index.asp , it states " Note : you must meet the minimum requirements for your application to be eligible for processing . "'
# Processed and saved representation for token ''s' in sentence: 'Amnesty chief spokesman Mike Blakemore said : " It 's unbelievable that no one can account for 200,000 assault rifles .'
# Processed and saved representation for token 'for' in sentence: 'But as its economy has expanded by an average of nine per cent per year for the last two decades , so has its demand for energy .'
# Processed and saved representation for token 'emissions' in sentence: '25 - Percentage of overall worldwide carbon dioxide emissions the United States is responsible for .'
# Processed and saved representation for token 'for' in sentence: 'I am a 20 something gay black male and I am looking for suggestions on neighborhoods close to the downtown Toronto area .'

# %%
import pandas as pd
from google.colab import files

# Step 1: Convert each list of dictionaries in `reps` to a DataFrame and save to CSV
for key, representation_list in reps.items():
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(representation_list)

    # Define the file name for each marker
    file_name = f"{key}_representations.csv"

    # Step 2: Save each DataFrame to a CSV file
    df.to_csv(file_name, index=False)

    # Step 3: Download the file to your local computer
    files.download(file_name)

# %%
for key, value in reps.items():
  print(key)
# Out:
# plural_noun_sentences
# third_person_present_sentences
# accusative_case_sentences
# genitive_case_sentences
# dative_case_sentences
# sublative_case_sentences
# translative_case_sentences
# causal_final_case_sentences

# %%
import pandas as pd
from google.colab import files

# Check if "Accusative" exists in `reps`
if "accusative_case_sentences" in reps:
    # Convert the "Accusative" representation list to a DataFrame
    df_accusative = pd.DataFrame(reps["accusative_case_sentences"])

    # Define the file name for the Accusative marker
    file_name = "Accusative_representations.csv"

    # Save the DataFrame to a CSV file
    df_accusative.to_csv(file_name, index=False)

    # Download the file to your local computer
    files.download(file_name)
else:
    print("The 'Accusative' marker was not found in reps.")

# %%
for key, value in reps.items():
    print(key)
    print(len(value))
# Out:
# plural_noun_sentences
# 2173
# third_person_present_sentences
# 619
# accusative_case_sentences
# 163
# genitive_case_sentences
# 368
# dative_case_sentences
# 512
# sublative_case_sentences
# 474
# translative_case_sentences
# 88
# causal_final_case_sentences
# 694
