# %% [markdown]
# # Inference of the Hungarian model representations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path='/content/drive/My Drive/Colab Notebooks/Experiments_NLP/raw_input.csv'
import pandas as pd
df = pd.read_csv(file_path, sep='\t')
print(df.head())
# Out:
#    Unnamed: 0        Word       Lemma    POS Case Number  Person Tense Mood  \
# 0           0           A           a    DET  NaN    NaN     NaN   NaN  NaN
# 1           1  csatkarika  csatkarika   NOUN  Nom   Sing     NaN   NaN  NaN
# 2           2    felirata     felirat   NOUN  Nom   Sing     NaN   NaN  NaN
# 3           3           a           a    DET  NaN    NaN     NaN   NaN  NaN
# 4           4           "           "  PUNCT  NaN    NaN     NaN   NaN  NaN
#
#   Voice  Form-Lemma Difference                   Subtokens  \
# 0   NaN                      0                       ['A']
# 1   NaN                      0  ['csat', '##kar', '##ika']
# 2   NaN                      1          ['felirat', '##a']
# 3   NaN                      0                       ['a']
# 4   NaN                      0                       ['"']
#
#          Subtoken IDs  Subtoken Start Index  Subtoken End Index  \
# 0              [2038]                     0                   0
# 1  [3487, 7268, 2986]                     1                   3
# 2      [12069, 31735]                     4                   5
# 3              [2005]                     6                   6
# 4              [2561]                     7                   7
#
#                           BERT Subtokenized Sentence  \
# 0  A csat ##kar ##ika felirat ##a a " magas " , "...
# 1  A csat ##kar ##ika felirat ##a a " magas " , "...
# 2  A csat ##kar ##ika felirat ##a a " magas " , "...
# 3  A csat ##kar ##ika felirat ##a a " magas " , "...
# 4  A csat ##kar ##ika felirat ##a a " magas " , "...
#
#                                             Sentence
# 0  A csatkarika felirata a " magas " , " ég " , "...
# 1  A csatkarika felirata a " magas " , " ég " , "...
# 2  A csatkarika felirata a " magas " , " ég " , "...
# 3  A csatkarika felirata a " magas " , " ég " , "...
# 4  A csatkarika felirata a " magas " , " ég " , "...

# %%
import torch
import numpy as np
import pickle
from transformers import BertTokenizer, BertModel

# Load the BERT tokenizer and model with hidden states enabled
tokenizer = BertTokenizer.from_pretrained("SZTAKI-HLT/hubert-base-cc")
model = BertModel.from_pretrained("SZTAKI-HLT/hubert-base-cc", output_hidden_states=True)

# Move the model to GPU
model = model.to('cuda')

# Ensure the model is in evaluation mode
model.eval()


def extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Accusative', marker_column='Case'):
    # Use half of the dataset
    df_half = df.sample(frac=0.5, random_state=42)  # Using half of the dataset

    representations = []  # List to store all representations in memory

    for idx, row in df_half.iterrows():
        sentence = row['Sentence']
        encoded_input = tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=512, add_special_tokens=True)

        # Move tokenized input to GPU
        encoded_input = {key: value.to('cuda') for key, value in encoded_input.items()}

        # Process the sentence
        with torch.no_grad():
            outputs = model(**encoded_input)
            all_hidden_states = outputs.hidden_states

        # Get the length of the tokenized sentence (excluding padding)
        tokenized_length = (encoded_input['input_ids'] != tokenizer.pad_token_id).sum(dim=1) - 2

        subtoken_end_idx = row['Subtoken End Index']

        # Ensure subtoken_end_idx is within the tokenized length for this sentence
        if subtoken_end_idx > tokenized_length.item():
            print(f"Skipping token '{row['Word']}' in sentence '{row['Sentence']}' because subtoken_end_idx exceeds tokenized length.")
            torch.cuda.empty_cache()  # Clear GPU memory
            continue

        # Check if the token belongs to the class you're interested in
        if row[marker_column] == class_label:
            # Extract hidden states for the given subtoken end index for all layers
            token_representations_all_layers = [layer_output[0, subtoken_end_idx + 1, :].cpu().numpy() for layer_output in all_hidden_states]

            # Create the dictionary for the current sentence
            representation = {
                'Word': row['Word'],
                'Lemma': row['Lemma'],
                'Sentence': row['Sentence'],
                'Hidden Representations (All Layers)': token_representations_all_layers,
                'Accusative': int(row['Case'] == 'Acc'),
                'Genitive': int(row['Case'] == 'Gen'),
                'Dative': int(row['Case'] == 'Dat'),
                'Sublative': int(row['Case'] == 'Sbl'),
                'CausalFinal': int(row['Case'] == 'Cau'),
                'Translative': int(row['Case'] == 'Tra'),
                'Plural': int(row['Number'] == 'Plur'),
                'VerbConjugation': int(row['POS'] == 'VERB')
            }

            # Save each sentence's representation to file incrementally
            with open(output_file, 'ab') as f:
                pickle.dump(representation, f)

            # Add to the list to keep in memory
            representations.append(representation)

            # Print confirmation for each sentence processed
            print(f"Processed and saved representation for token '{row['Word']}' in sentence: '{row['Sentence']}'")

        # Clear GPU memory after each sentence
        torch.cuda.empty_cache()

    # Return all representations stored in memory
    return representations
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
print(len(representations_gen))
print('gen')
print(len(representations_acc))
print('acc')
print(len(representations_dat))
print('dat')
print(len(representations_subl))
print('subl')
print(len(representations_tra))
print('tran')
print(len(representations_plur))
print('plural')
print(len(representations_conj))
print('conj')
print(len(representations_cau))
print('cau')
# Out:
# 154
# gen
# 1023
# acc
# 142
# dat
# 312
# subl
# 49
# tran
# 1617
# plural
# 1905
# conj
# 75
# cau

# %%
import pickle
from google.colab import files

# Function to save a representation using pickle and download
def save_and_download_representation(rep, filename):
    with open(f'{filename}.pkl', 'wb') as f:
        pickle.dump(rep, f)
    files.download(f'{filename}.pkl')

# Save and download each representation object
save_and_download_representation(representations_gen, 'representations_gen')
save_and_download_representation(representations_acc, 'representations_acc')
save_and_download_representation(representations_dat, 'representations_dat')
save_and_download_representation(representations_subl, 'representations_subl')
save_and_download_representation(representations_cau, 'representations_cau')
save_and_download_representation(representations_tra, 'representations_tra')
save_and_download_representation(representations_plur, 'representations_plur')
save_and_download_representation(representations_conj, 'representations_conj')

# %%
representations_gen = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Gen', marker_column='Case')
representations_acc = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Acc', marker_column='Case')
representations_dat = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Dat', marker_column='Case')
representations_subl = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Sbl', marker_column='Case')
representations_cau = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Cau', marker_column='Case')
representations_tra = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Tra', marker_column='Case')
representations_plur = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='Plur', marker_column='Number')
representations_conj = extract_bert_hidden_representations_by_class(df, output_file="representations_class.pkl", model=model, tokenizer=tokenizer, class_label='VERB', marker_column='POS')
# Out:
# Streaming output truncated to the last 5000 lines.
# A tiltólistára kerülésre egy új kislemez lett a válasz .	kerülésre	2	Sub
# Miley nemrég költözött el Tennessee-ből és most Malibu-ban hódít tehetségével .	tehetségével	9	Ins
# ez a kérdés bizonyára napirendre kerül majd a pénzügyi terv felülvizsgálatakor .	felülvizsgálatakor	10	Tem
# Egy , az alapítás óta a szervezetnél lévő tag a fennálló helyzetet a Jobbik 2010 előtti kommunikációjához hasonlította .	szervezetnél	6	Ade
# Miért és mivel küzd ma egy vidéki egyetem , és hol a jövő a hallgatók számára a fővárostól egy aránylag messzi távolságban .	távolságban	21	Ine
# Egy effektet , a lábdobot vagy más hangzást kiválasztani és keverni csak minőségi felszereléssel lehet .	hangzást	7	Acc
# Különösen veszélyeztetettek az alkohol- és drogfogyasztók , de a számítógép- vagy játékgép-függő fiatalok , valamint a nagyon szoros párkapcsolatba bevonódó személyek egyaránt .	párkapcsolatba	18	Ill
# Egyébként a 99%-ot nem a cigányság összlakossághoz viszonyított arányából kifolyólag írtam , hanem mert az ilyen jellegű , ilyen módon elkövetett bűncselekmények elkövetői szinte mindig cigányok .	arányából	8	Ela
# A csodálatos átalakulás lényegében a polaritás elvén jön létre , azon az elméleten , hogy minden lény és megtestesülés magában hordozza önmaga kiegészítő , „ másik felét ” , azaz poláris ellentétjét .	megtestesülés	18	Nom
# A máriaremetei templomig , az ellenőrzőpontig együtt megyünk , és egy jót beszélgetünk .	templomig	2	Ter
# Következésképp egyáltalán NEM tanácsos megbízni a programban , fizetni érte pedig végképp nem ajánlott , mert nemcsak kidobott pénz lenne , hanem veszélyes kezekbe is juttathatja személyes adatait .	kezekbe	23	Ill
# A rendezői önmegvalósítást , színházi önmutogatást halálos vétek a gyerekekre rászabadítani , valamint azokat az produkciókat , amelyek a gyereknek ez is jó lesz alapelvével pénzkeresési céllal tehetség nélkül születtek .	önmutogatást	5	Acc
# A tanárok írhatnak egyedi jellemzéseket a diákokról , de rendelkezésükre állnak értékelési minták is , amikben az előre meghatározott kulcsszavakat lehet kiválasztani .	diákokról	6	Del
# A KÖZÉRDEKŰ BEJELENTÉSEK ÉS PANASZOK KEZELÉSÉNEK RENDJÉRŐL Jászberény Város Jegyzője tekintettel az európai uniós csatlakozással összefüggő egyes törvények módosításáról szóló 2004. évi XXIX. törvény 141 .	RENDJÉRŐL	6	Del
# A víz időközben nem hűlt ki , de én mégis úgy dideregtem mintha kihűlt volna … Innen a jobb lábamat már nem nagyon használtam , a műtött , de kiválóan funkcionáló ballal rugdostam a vizet , eléggé koordinálatlanul .	ballal	31	Ins
# Egy fiatal politikai párt vezetője behatolt az Origo szerkesztőségébe , hogy fenyegető stílusban számon kérje az újságírókat a pártról és annak pénzügyeiről szóló cikk miatt .	szerkesztőségébe	8	Ill
# 70-kilogrammos kadettek között Plesovszki Milán , juniorban Szilasi János szerzett aranyat a klubnak .	juniorban	6	Ine
# ( 16) Az a pedagógus , aki e törvény hatálybalépésekor az ötvenkettedik életévét betöltötte , pedagógus-továbbképzésben történõ részvételre nem kötelezhetõ .	hatálybalépésekor	9	Tem
# Az alperes fellebbezésében az elsıfokú ítélet megváltoztatását , a kereset elutasítását kérte .	fellebbezésében	2	Ine
# Munkaviszony létesítésekor a legtöbb munkáltató próbaidőt köt ki , hogy jobban megismerhesse a munkavállalót és annak szakmai kvalitásait , személyiségét .	létesítésekor	1	Tem
# Lényeges , hogy a logót minőségveszteség nélkül tudjuk nagyítani , ugyanis a cég logójának ugyanúgy kell kinéznie egy levélpapíron , egy weboldalon , és egy óriásplakáton is !	logójának	13	Dat
# Ez még – saját elmondása szerint – a Morgan Stanley-nek abban az időszakában volt , amikor még nem alakult át az egész bankszektor a Wall Street farkasává .	farkasává	26	Tra
# Alapításakor , 2004-ben Mark néhány évfolyamtársával dolgozott össze egy olyan oldal megalkotása céljából , ahol a Harvard Egyetem tanulói kapcsolatba léphetnek egymással .	Alapításakor	0	Tem
# Az utasok eligazodását segítheti a Debrecen Airport letölthető applikációja is , amelyben az összes repülőtéri szolgáltatásról tájékozódhatnak a nap 24 órájában .	szolgáltatásról	15	Del
# Az meg még kevésbé szopás , hogy a hangzásért felelős Sándor Dániel egy ideje az Isten Háta Mögött-ben is építi renoméját , így tehát matematikai képletekkel levezethető , mekkora kvltbandának is számít régi csapata hetedhéthatáron innen és onnan .	hangzásért	8	Cau
# Ezek a növények idegentermékenyülők , ezért a kiválasztott fajta bimbó korban tüllzacskóval szigetelt virágait kinyílásuk után mesterségesen összeporozzuk ( az egyik növény virágáról szedett pollent a másik növény virágjának bibéjére kenjük ) .	virágáról	22	Del
# Karvalits Ferenc , az MNB alelnöke hétfői sajtótájékoztatóján azt mondta : a magyar gazdaság változatlanul lassan növekszik , és az inflácó csökkenése sem gyorsult .	inflácó	20	Nom
# Épp saját regényen dolgozik , ami halakról fog szólni és ebben is nagy szerepe van a tanítónénijének .	regényen	2	Sup
# Zárásként egy közös zenélés , éneklés következett különböző hangszerekkel , melyeken hallgatónk ( Józsi ) énekelt és zenélt ( gitárral , dobolással ) .	hangszerekkel	8	Ins
# Azt már eddig is megszokhattuk , hogy a demokráciáért és az emberi jogokért aggódó gittegyletek rendre elfogult , a valósággal köszönőviszonyban sem lévő megállapításokat tesznek a világ országaival kapcsolatban .	demokráciáért	8	Cau
# Most meg egy egyszerű , de talpraesett bonni kávéházas miatt visszavonultak .	kávéházas	8	Nom
# A sérülésnek van egy lelket facsaró kegyetlensége .	sérülésnek	1	Dat
# A használt lakókocsik vásárlásakor a futott kilométerek számánál jobban kell figyelni a berendezés állagára .	vásárlásakor	3	Tem
# azokról a lehetőségekről , technikai eszközökről , amelyekkel még a szerződéses nyilatkozat elküldését megelőzően kijavíthatók az esetleges hibák .	eszközökről	5	Del
# Tudta , hogy egy szépségverseny jó kiindulási alap lehet az ismertséghez és az ügynökök figyelméhez , ezért indult az 1978-as Miss Orange County szépségversenyen és meg is nyerte azt .	figyelméhez	14	All
# Eljárási költség megtérítéséről nem kellett dönteni , mert az eljárás során ilyen költség nem merült fel .	megtérítéséről	2	Del
# Maffiák , kartellek , meg a tudatlan suttyók végül is azt csinálnak a mindenféle puncs-panccsal , amit csak akarnak , míg mindenki be nem csavarodik , beteggé nem lesz , és bele nem döglik , végül ?	puncs-panccsal	14	Ins
# Miután lerázta a bandát , visszatért a lokálhoz , a megszúrt Ivan Pesic testét a veséjénél elszorította , csökkentve ezzel a vérzést , majd vállára kapva a kórházig szaladt a kétméteres kapussal .	kórházig	27	Ter
# ( 1150 k. ) , a cefalui ( 1148) és a monrealei szegyh .	cefalui	6	Nom
# Ha azonban a mért görbéket az adott görbe +30 mv-nál mért vezet képesség értékére , mint maximumra normalizáltuk , a kapott vezet képesség-feszültség összefüggések nem különböztek egymástól ( 4/C. ábra ) .	maximumra	16	Sub
# A helység párttitkáráról volt szó .	párttitkáráról	2	Del
# Egy hosszabb , több éves munkaviszony esetén könnyen előfordulhat , hogy a munkáltató a versenytilalom ellenértékeként végül nagyobb összeget fizet meg a munkavállaló részére , mintha nem havonta fizetne , hanem csupán a munkaviszony megszűnésekor .	megszűnésekor	34	Tem
# Delben 10 solert ebedeltunk 1/4 csirket , krumplival , salataval , fagyival es inka kolaval .	kolaval	14	Ins
# A fiuk a banyaban kevesen dolgoznak !	banyaban	3	Sup
# Szóval , itt csak annyi a dolga , hogy 1,5 dl langyos vízbe tesz egy púpozott evőkanál lisztet , egy kiskanál kristálycukrot és az élesztőt belemorzsolva .	kristálycukrot	21	Acc
# Kínálatunkban megtalálhatók a legegyszerűbb diszk alapú DAS és NAS rendszerek és a legnagyobb SAN architektúrába tartozó tárolók , illetve a különböző szalagos rendszerek is .	architektúrába	14	Ill
# Ahogy korábban megírtuk , a tárgy meglepetés volt a Főúri utazások , úti kalandok kiállítás két éves évfordulós ünnepségéig .	ünnepségéig	18	Ter
# 2009 január 20-án , a beiktatási bálon Barack ésMichelle Obamaelső táncánál , Beyoncé énekelhette el nekik Etta James  At Last " című dalát .' because subtoken_end_idx exceeds tokenized length.
# Skipping token 'egyáltalán' in sentence ' Az építészet valósága a teste : az , ami konkrét , ami formává , tömeggé , és térré vált .	formává	13	Tra
# Az Óvodák és Kollégium főkönyvi könyvelésének alapját az ún. könyvelési támlapok ,- melyek az alapbizonylatok kontírozása alapján készülő összesítő táblázatok- biztosítják .	könyvelésének	5	Dat
# Közben azonban az állami kézbe került kórházaknál folyamatosan járnak le a különféle szállítási szerződések .	kórházaknál	6	Ade
# Orosvári olyan fontos részletekre is gondolt , hogy olyantól rendeljen , aki biztosítani tudja , hogy minden megyeszékhelyen javítani vagy cserélni tudják majd az ágyakat , ha később erre szükség lenne .	megyeszékhelyen	17	Sup
# Miki Satoshi többi filmjéhez hasonlóan ez sem elsősorban a színészi játék terén emelkedik ki , hiszen vígjátékhoz méltóan mindenki egy kicsit túljátsza a szerepét , bár közel sincs akkora grimaszolás , mint a hongkongi komédiákban .	filmjéhez	3	All
# Volt idő mikor még nem ez volt a trend , de én is csak ezt látom , ismerősöknél , idegeneknél , imádnak nekem mesélni , minden korosztály .	ismerősöknél	17	Ade
# Vágjon bele az előadásába !	előadásába	3	Ill
# A Népszabadság kiadója , a Mediaworks szombattól függesztette fel a nyomtatott lap és a Népszabadság Online kiadását “ a lap új koncepciójának kialakításáig , illetve megvalósításáig ” – állt a hivatalos közleményben .	megvalósításáig	25	Ter
# A ransomware-ek jellegzetessége , hogy zárolják a gépen tárolt adatainkat , és azokat csak váltságdíjért cserébe oldják fel a támadók .	váltságdíjért	14	Cau
# Pillanatig sem csodálkozom , hogy úgy en bloc ez nem segíti elő a véleménypolarozációt .	Pillanatig	0	Ter
# Idővel ő is képes lesz kezelni a helyzetet , megtanulja , hogyan kell viselkedni az egyik óvónénivel és hogyan a másikkal .	óvónénivel	16	Ins
# A kitelepítésről , internálásról , illetve a katonai munkaszolgálatról 4.3 .	kitelepítésről	1	Del
# Halat a horgászoktól ?	horgászoktól	2	Abl
# - Különösen fontos ilyenkor a törzs tartóizmainak , a hát- és a hasizomnak az erősítése – ebben hatalmas segítséget jelenthet a szakorvos , a személyi edzők , a gyógytornász által felépített mozgásprogram .	hasizomnak	12	Dat
# Akik először vettek rszt gyertyás körmeneten , azoknak egy letre maradandó lmnyt nyújtott .	rszt	3	Acc
# Próbálkozott már a cégvezér automatizált gyárakkal , de ezekben a drasztikusan alacsony személyzet miatt olyan gyorsan uralkodott el a káosz , hogy még az örök optimista vezérigazgatónak is be kellett látnia , nem túl működőképes az ötlet .	vezérigazgatónak	26	Dat
# 10. Szűrőzés , digitális és analóg labortrükkök	labortrükkök	6	Nom
# A rák esetében a tanulmány bizonyítékai vegyes képet mutatnak , de kétségtelen , hogy szoros a kapcsolat a fokozott fizikai aktivitás és a vastagbélrák kialakulás esélyének csökkentése között mindkét nemnél .	nemnél	29	Ade
# A szakemberrel gyakran találkozhatunk intézményi , vállalati és lakossági befektetők számára rendezett szakmai konferenciákon , továbbképzéseken , emellett folyamatos médiaszereplésével aktív szerepet vállal a hazai befektetők gazdasági , pénzügyi és befektetési ismereteinek bővítésében .	továbbképzéseken	15	Sup
# Eddig három szervezetet , a Váralja Szövetséget , az Élőlánc Magyarországért Pártot , valamint a Gazdálkodó Családok Szövetségét jelölte meg mozgalma alapítójaként .	alapítójaként	21	Ess
# Érdeklődéssel olvasom , hogy animációval és multimédiával is foglalkozik .	animációval	4	Ins
# A lisztet összekeverjük a sütőporral , a vaníliás cukorral , és a reszelt citromhéjjal .	sütőporral	4	Ins
# Úgy hisszük apánk egy megtört ember volt , aki bánatában kiontotta önnön életét .	bánatában	9	Ine
# A szakember véleménye a kliens motivációjáról , együttműködési hajlandóságáról a kapcsolatfelvétel időpontjában .	hajlandóságáról	8	Del
# A szerethető , egyedi , downtempo zenét játszó zenekar jelenlegi tagjai Hártó Szilvia , Menyhárt Leó , Koroknay András és Asztalos Zoltán .	downtempo	5	Nom
# A gabionfalakat leggyakrabban támfalként , kerítés támfalaként használják , ilyenkor előre elkészített alapra rakják a kosarakat , majd erre a következő sorokat , amíg el nem érik a kívánt magasságot .	támfalaként	6	Ess
# A hír újabb mélységekbe lökte a telekommunikációs cég részvényeinek árfolyamát .	mélységekbe	3	Ill
# A tiltólistára kerülésre egy új kislemez lett a válasz .	kerülésre	2	Sub
# Miley nemrég költözött el Tennessee-ből és most Malibu-ban hódít tehetségével .	tehetségével	9	Ins
# ez a kérdés bizonyára napirendre kerül majd a pénzügyi terv felülvizsgálatakor .	felülvizsgálatakor	10	Tem
# Egy , az alapítás óta a szervezetnél lévő tag a fennálló helyzetet a Jobbik 2010 előtti kommunikációjához hasonlította .	szervezetnél	6	Ade
# Miért és mivel küzd ma egy vidéki egyetem , és hol a jövő a hallgatók számára a fővárostól egy aránylag messzi távolságban .	távolságban	21	Ine
# Egy effektet , a lábdobot vagy más hangzást kiválasztani és keverni csak minőségi felszereléssel lehet .	hangzást	7	Acc
# Különösen veszélyeztetettek az alkohol- és drogfogyasztók , de a számítógép- vagy játékgép-függő fiatalok , valamint a nagyon szoros párkapcsolatba bevonódó személyek egyaránt .	párkapcsolatba	18	Ill
# Egyébként a 99%-ot nem a cigányság összlakossághoz viszonyított arányából kifolyólag írtam , hanem mert az ilyen jellegű , ilyen módon elkövetett bűncselekmények elkövetői szinte mindig cigányok .	arányából	8	Ela
# A csodálatos átalakulás lényegében a polaritás elvén jön létre , azon az elméleten , hogy minden lény és megtestesülés magában hordozza önmaga kiegészítő , „ másik felét ” , azaz poláris ellentétjét .	megtestesülés	18	Nom
# A máriaremetei templomig , az ellenőrzőpontig együtt megyünk , és egy jót beszélgetünk .	templomig	2	Ter
# Következésképp egyáltalán NEM tanácsos megbízni a programban , fizetni érte pedig végképp nem ajánlott , mert nemcsak kidobott pénz lenne , hanem veszélyes kezekbe is juttathatja személyes adatait .	kezekbe	23	Ill
# A rendezői önmegvalósítást , színházi önmutogatást halálos vétek a gyerekekre rászabadítani , valamint azokat az produkciókat , amelyek a gyereknek ez is jó lesz alapelvével pénzkeresési céllal tehetség nélkül születtek .	önmutogatást	5	Acc
# A tanárok írhatnak egyedi jellemzéseket a diákokról , de rendelkezésükre állnak értékelési minták is , amikben az előre meghatározott kulcsszavakat lehet kiválasztani .	diákokról	6	Del
# A KÖZÉRDEKŰ BEJELENTÉSEK ÉS PANASZOK KEZELÉSÉNEK RENDJÉRŐL Jászberény Város Jegyzője tekintettel az európai uniós csatlakozással összefüggő egyes törvények módosításáról szóló 2004. évi XXIX. törvény 141 .	RENDJÉRŐL	6	Del
# A víz időközben nem hűlt ki , de én mégis úgy dideregtem mintha kihűlt volna … Innen a jobb lábamat már nem nagyon használtam , a műtött , de kiválóan funkcionáló ballal rugdostam a vizet , eléggé koordinálatlanul .	ballal	31	Ins
# Egy fiatal politikai párt vezetője behatolt az Origo szerkesztőségébe , hogy fenyegető stílusban számon kérje az újságírókat a pártról és annak pénzügyeiről szóló cikk miatt .	szerkesztőségébe	8	Ill
# 70-kilogrammos kadettek között Plesovszki Milán , juniorban Szilasi János szerzett aranyat a klubnak .	juniorban	6	Ine
# ( 16) Az a pedagógus , aki e törvény hatálybalépésekor az ötvenkettedik életévét betöltötte , pedagógus-továbbképzésben történõ részvételre nem kötelezhetõ .	hatálybalépésekor	9	Tem
# Az alperes fellebbezésében az elsıfokú ítélet megváltoztatását , a kereset elutasítását kérte .	fellebbezésében	2	Ine
# Munkaviszony létesítésekor a legtöbb munkáltató próbaidőt köt ki , hogy jobban megismerhesse a munkavállalót és annak szakmai kvalitásait , személyiségét .	létesítésekor	1	Tem
# Lényeges , hogy a logót minőségveszteség nélkül tudjuk nagyítani , ugyanis a cég logójának ugyanúgy kell kinéznie egy levélpapíron , egy weboldalon , és egy óriásplakáton is !	logójának	13	Dat
# Ez még – saját elmondása szerint – a Morgan Stanley-nek abban az időszakában volt , amikor még nem alakult át az egész bankszektor a Wall Street farkasává .	farkasává	26	Tra
# Alapításakor , 2004-ben Mark néhány évfolyamtársával dolgozott össze egy olyan oldal megalkotása céljából , ahol a Harvard Egyetem tanulói kapcsolatba léphetnek egymással .	Alapításakor	0	Tem
# Az utasok eligazodását segítheti a Debrecen Airport letölthető applikációja is , amelyben az összes repülőtéri szolgáltatásról tájékozódhatnak a nap 24 órájában .	szolgáltatásról	15	Del
# Az meg még kevésbé szopás , hogy a hangzásért felelős Sándor Dániel egy ideje az Isten Háta Mögött-ben is építi renoméját , így tehát matematikai képletekkel levezethető , mekkora kvltbandának is számít régi csapata hetedhéthatáron innen és onnan .	hangzásért	8	Cau
# Ezek a növények idegentermékenyülők , ezért a kiválasztott fajta bimbó korban tüllzacskóval szigetelt virágait kinyílásuk után mesterségesen összeporozzuk ( az egyik növény virágáról szedett pollent a másik növény virágjának bibéjére kenjük ) .	virágáról	22	Del
# Karvalits Ferenc , az MNB alelnöke hétfői sajtótájékoztatóján azt mondta : a magyar gazdaság változatlanul lassan növekszik , és az inflácó csökkenése sem gyorsult .	inflácó	20	Nom
# Épp saját regényen dolgozik , ami halakról fog szólni és ebben is nagy szerepe van a tanítónénijének .	regényen	2	Sup
# Zárásként egy közös zenélés , éneklés következett különböző hangszerekkel , melyeken hallgatónk ( Józsi ) énekelt és zenélt ( gitárral , dobolással ) .	hangszerekkel	8	Ins
# Azt már eddig is megszokhattuk , hogy a demokráciáért és az emberi jogokért aggódó gittegyletek rendre elfogult , a valósággal köszönőviszonyban sem lévő megállapításokat tesznek a világ országaival kapcsolatban .	demokráciáért	8	Cau
# Most meg egy egyszerű , de talpraesett bonni kávéházas miatt visszavonultak .	kávéházas	8	Nom
# A sérülésnek van egy lelket facsaró kegyetlensége .	sérülésnek	1	Dat
# A használt lakókocsik vásárlásakor a futott kilométerek számánál jobban kell figyelni a berendezés állagára .	vásárlásakor	3	Tem
# azokról a lehetőségekről , technikai eszközökről , amelyekkel még a szerződéses nyilatkozat elküldését megelőzően kijavíthatók az esetleges hibák .	eszközökről	5	Del
# Tudta , hogy egy szépségverseny jó kiindulási alap lehet az ismertséghez és az ügynökök figyelméhez , ezért indult az 1978-as Miss Orange County szépségversenyen és meg is nyerte azt .	figyelméhez	14	All
# Eljárási költség megtérítéséről nem kellett dönteni , mert az eljárás során ilyen költség nem merült fel .	megtérítéséről	2	Del
# Maffiák , kartellek , meg a tudatlan suttyók végül is azt csinálnak a mindenféle puncs-panccsal , amit csak akarnak , míg mindenki be nem csavarodik , beteggé nem lesz , és bele nem döglik , végül ?	puncs-panccsal	14	Ins
# Miután lerázta a bandát , visszatért a lokálhoz , a megszúrt Ivan Pesic testét a veséjénél elszorította , csökkentve ezzel a vérzést , majd vállára kapva a kórházig szaladt a kétméteres kapussal .	kórházig	27	Ter
# ( 1150 k. ) , a cefalui ( 1148) és a monrealei szegyh .	cefalui	6	Nom
# Ha azonban a mért görbéket az adott görbe +30 mv-nál mért vezet képesség értékére , mint maximumra normalizáltuk , a kapott vezet képesség-feszültség összefüggések nem különböztek egymástól ( 4/C. ábra ) .	maximumra	16	Sub
# A helység párttitkáráról volt szó .	párttitkáráról	2	Del
# Egy hosszabb , több éves munkaviszony esetén könnyen előfordulhat , hogy a munkáltató a versenytilalom ellenértékeként végül nagyobb összeget fizet meg a munkavállaló részére , mintha nem havonta fizetne , hanem csupán a munkaviszony megszűnésekor .	megszűnésekor	34	Tem
# Delben 10 solert ebedeltunk 1/4 csirket , krumplival , salataval , fagyival es inka kolaval .	kolaval	14	Ins
# A fiuk a banyaban kevesen dolgoznak !	banyaban	3	Sup
# Szóval , itt csak annyi a dolga , hogy 1,5 dl langyos vízbe tesz egy púpozott evőkanál lisztet , egy kiskanál kristálycukrot és az élesztőt belemorzsolva .	kristálycukrot	21	Acc
# Kínálatunkban megtalálhatók a legegyszerűbb diszk alapú DAS és NAS rendszerek és a legnagyobb SAN architektúrába tartozó tárolók , illetve a különböző szalagos rendszerek is .	architektúrába	14	Ill
# Ahogy korábban megírtuk , a tárgy meglepetés volt a Főúri utazások , úti kalandok kiállítás két éves évfordulós ünnepségéig .	ünnepségéig	18	Ter
# 2009 január 20-án , a beiktatási bálon Barack ésMichelle Obamaelső táncánál , Beyoncé énekelhette el nekik Etta James  At Last " című dalát .' because subtoken_end_idx exceeds tokenized length.
# Processed and saved representation for token 'áldozni' in sentence: 'Ennek társadalmi költségei úgy mérsékelhetők , hogy az állomások kereskedelmi funkcióinak megszervezésével azok üzemeltetésébe bekapcsolódott magántőke a saját üzletének védelme érdekében legyen kész áldozni a rend fenntartására .'
# Processed and saved representation for token 'összekötötték' in sentence: 'A műtét során a sebészek 16 elektródát helyeztek el a lumboszakrális ( ágyék és keresztcsont környéki ) gerincvelőbe , és összekötötték azokat az idegkötegekkel , melyek a boka , a csípő , a térd és a lábujjak mozgását kontrollálják .'
# Processed and saved representation for token 'szűrtünk' in sentence: 'Egyelőre hátul is jól szűrtünk , a félidő derekáig kevés lehetősége volt a " kanáriknak " .'
# Skipping token ',' in sentence ' Tudathasadásos állapot aktív dolgozóként a szépkorúságra gondolni .	szépkorúságra	6	Sub
# Ezek az öt milliméteresnél kisebb műanyagrészecskéket a halak tápláléknak hiszik , megeszik , valamint bekerülnek a városok vízvezetékrendszerébe is .	vízvezetékrendszerébe	17	Ill
# Igyekszünk tudásunkkal és munkáinkkal olyan megjelenést teremteni partnereinknek , melyet a legoptimálisabban alkalmazhatnak mind image , mind akció , mind eseményorientált felhasználás során .	munkáinkkal	3	Ins
# A történet , az események felelevenítésére használhatjuk a lánc- és a	felelevenítésére	5	Sub
# Extra laktató reggeli egy nyaralás emlékére Még valamikor kamaszkoromban , az akkori barátoméknál ettem először parasztreggelit .	barátoméknál	12	Ade
# HIRDETMÉNY NEMZETI FÖLDLPB TRTOZÓ FÖLDRÉSZLETEK NYILVÁNOS PÁLYÁZTTÁS , ILLETVE ÁRVERÉS MELLŐZÉSÉVEL TÖRTÉNŐ ÉRTÉKESÍTÉSÉNEK 2015/II .	HIRDETMÉNY	0	Nom
# BÜNTETÉS-VÉGREHAJTÁSI JOG TÉTELEK ÉS AZ ELSAJÁTÍTANDÓ JOGANYAG a Büntető Törvénykönyvről szóló 2012. évi C. törvény ( Btk. ) a büntetőeljárásról szóló 1998. évi XIX. törvény	JOGANYAG	6	Nom
# Április 18-án , vasárnap egy remeknek ígérkező kirándulásra várjuk a természetbarátokat a Sitkei-kápolnához .	Sitkei-kápolnához	12	All
# Beklen a Nagykunsági Civil Társadalomért Alapítvány 7 .	Társadalomért	4	Cau
# Robog tovább a Delta Vision retro turnénk , aminek heti főszereplője J. Goldenlane rendkívül szórakoztató poszt-apokaliptikus sci-fije , a Holdnak árnyéka .	Holdnak	19	Dat
# Konkoly Csaba leginkább két dolgot fájlal : taktikailag nem sikerült újítaniuk a meccs során , ráadásul hat-nyolc gólos hátrányban csapatként is szétestek a győriek , ami eddig nem igazán volt rájuk jellemző .	csapatként	19	Ess
# Egy valóban trú metálos pandát nem a WWF logójában , sokkal inkább a COF koncertjein lát !	logójában	8	Ine
# Etalont sajnos nem tudok senki éjjeliszekrényére helyezni .	éjjeliszekrényére	5	Sub
# Van valami ebben a Titansben , ami számomra lehengerlővé avanzsálja az egész gárdát és az egyik legerősebb címmé teszi a jelenlegi DC felhozatalban .	címmé	17	Tra
# A vaklicitnek köszönhetően 2012-ben 7,5 milliárd forintot takaríthattak meg a betegek , 2013-ban további 2,2 milliárd forinttal kellett kevesebbet fizetniük a gyógyszereikért .	gyógyszereikért	21	Cau
# Párosban Péter Ákossal izgalmas 3 szettes mérkőzésen kapott ki a döntőben a pécsi riválisoktól , és ezúttal a Szenjai – Pytel duó nyert .	riválisoktól	13	Abl
# Elsősorban nem is a lótól , inkább a lovastól , akinek eleinte nehezebben megy , hogy ráérezzen egy új ló mozgására , a segítségadások mértékére .	lótól	4	Abl
# Néhány misztikus visszavonul a világi tevékenységektől , és a teljes figyelmét az Istennel való misztikus egyesülésre összpontosítja .	tevékenységektől	5	Abl
# A voksokat hitek , elkötelezettségek irányítják , legkevésbé sem a tények , így nem szempont , hogy valójában mit képviselnek az egyes pártok , jelöltek .	voksokat	1	Acc
# A pecsétek gyűjtögetésének nem láttuk értelmét .	gyűjtögetésének	2	Dat
# 19 Fontos tudnivalók az OTDK-ra való nevezéssel kapcsolatban A helyi TDK konferencián tartott el adásával minden hallgató nevez a XXXI. Országos Tudományos Diákköri Konferenciára .	Konferenciára	23	Sub
# A THM számításnál az ügyfél által a pénzügyi intézménynek fizetett költségeket , valamint a harmadik személynek fizetett költségek közül az ügyfél által felajánlott fedezet értékbecslésének díját és lakásépítésnél a helyszíni szemlék díját kell figyelembe venni .	értékbecslésének	24	Dat
# Tájékoztató a teljesköltség-mutatóról a Nyugalom rendszeres díjas , klasszikus életbiztosításhoz Hatályos : 2017. január 1-jétől	életbiztosításhoz	9	All
# Mellékhatást egyáltalán semmit nem érzek , de az izmaimra jó hatása van.Így szeretném megkérdezni , hogy akkor nálam miért lehet hatásos , hisz nincs bizonyítottan myastheniám.Vagy miért nincs mellékhatása ?	izmaimra	8	Sub
# Az norvég ifjú balosokra győzelmi indulók helyett lebőgés várt .	balosokra	3	Sub
# Sűrűn , hatalmas pelyhekben hullt és kavargott a hó , s a reflektor fényében vidám zsibongó tánc vetült a zárka menyezetére .	pelyhekben	3	Ine
# Hangsúlyozta : az a céljuk , hogy a magyar ünnepekbe bekerüljön az ősökre való emlékezés .	ősökre	12	Sub
# Tanárként Debrecenben ( 12:26 ) , majd Sopronban helyezkedett el , s utóbbival kapcsolatban szól még a  kuruc-labanc " kulturális különbségről is ( 14:35 ) .' because subtoken_end_idx exceeds tokenized length.
# Processed and saved representation for token 'venni' in sentence: ' Az aktuális vastag tűzifa készleteinkről ( méret , fafaj , mennyiség ) az erdészeteinktől kaphat tájékoztatást .	erdészeteinktől	14	Abl
# A kapunyitáskor ezer ember költözött be a sátortáborba , a nulladik napon már háromezren buliztak .	kapunyitáskor	1	Tem
# Sztereotíp , rutinos munka , még a társadalmi osztályok közötti különbségtételnek sem tárgya .	különbségtételnek	10	Dat
# Természetesen minden tünetet komolyan kell venni , a karokba , hátba , nyakba sugárzó fájdalomtól a szédülésig , szorongásig .	szorongásig	18	Ter
# Vénségemig és megőszülésemig se hagyj el engem , ó Isten , hogy hirdessem a te karodat e nemzetségnek , és minden következendőnek a te nagy tetteidet. '
# Processed and saved representation for token 'hisznek' in sentence: 'Azoknak , akik szeretik Orbán Viktort , és hisznek a kormányfőnek , nekik ez egy ünnep , Magyarország megújulásának napja .'
# Processed and saved representation for token 'elhangzottak' in sentence: 'A Fidesz politikusa tájékoztatóját azzal zárta , hogy a találkozókon elhangzottak nyilvánosságra kerülésével “ a Portik - Laborc - ügy nem véget ért , hanem elkezdődött ” .'
# Processed and saved representation for token 'kezdte' in sentence: '- A morális gátlásait - kezdte Francis .'
# Processed and saved representation for token 'születik' in sentence: 'A „ Csoda születik ” produkciójában a közönség megismerkedhet a mozi elődjeivel és az első filmen rögzített tánclépésekkel .'
# Skipping token 'végképp' in sentence ' Az építészet valósága a teste : az , ami konkrét , ami formává , tömeggé , és térré vált .	formává	13	Tra
# Az Óvodák és Kollégium főkönyvi könyvelésének alapját az ún. könyvelési támlapok ,- melyek az alapbizonylatok kontírozása alapján készülő összesítő táblázatok- biztosítják .	könyvelésének	5	Dat
# Közben azonban az állami kézbe került kórházaknál folyamatosan járnak le a különféle szállítási szerződések .	kórházaknál	6	Ade
# Orosvári olyan fontos részletekre is gondolt , hogy olyantól rendeljen , aki biztosítani tudja , hogy minden megyeszékhelyen javítani vagy cserélni tudják majd az ágyakat , ha később erre szükség lenne .	megyeszékhelyen	17	Sup
# Miki Satoshi többi filmjéhez hasonlóan ez sem elsősorban a színészi játék terén emelkedik ki , hiszen vígjátékhoz méltóan mindenki egy kicsit túljátsza a szerepét , bár közel sincs akkora grimaszolás , mint a hongkongi komédiákban .	filmjéhez	3	All
# Volt idő mikor még nem ez volt a trend , de én is csak ezt látom , ismerősöknél , idegeneknél , imádnak nekem mesélni , minden korosztály .	ismerősöknél	17	Ade
# Vágjon bele az előadásába !	előadásába	3	Ill
# A Népszabadság kiadója , a Mediaworks szombattól függesztette fel a nyomtatott lap és a Népszabadság Online kiadását “ a lap új koncepciójának kialakításáig , illetve megvalósításáig ” – állt a hivatalos közleményben .	megvalósításáig	25	Ter
# A ransomware-ek jellegzetessége , hogy zárolják a gépen tárolt adatainkat , és azokat csak váltságdíjért cserébe oldják fel a támadók .	váltságdíjért	14	Cau
# Pillanatig sem csodálkozom , hogy úgy en bloc ez nem segíti elő a véleménypolarozációt .	Pillanatig	0	Ter
# Idővel ő is képes lesz kezelni a helyzetet , megtanulja , hogyan kell viselkedni az egyik óvónénivel és hogyan a másikkal .	óvónénivel	16	Ins
# A kitelepítésről , internálásról , illetve a katonai munkaszolgálatról 4.3 .	kitelepítésről	1	Del
# Halat a horgászoktól ?	horgászoktól	2	Abl
# - Különösen fontos ilyenkor a törzs tartóizmainak , a hát- és a hasizomnak az erősítése – ebben hatalmas segítséget jelenthet a szakorvos , a személyi edzők , a gyógytornász által felépített mozgásprogram .	hasizomnak	12	Dat
# Akik először vettek rszt gyertyás körmeneten , azoknak egy letre maradandó lmnyt nyújtott .	rszt	3	Acc
# Próbálkozott már a cégvezér automatizált gyárakkal , de ezekben a drasztikusan alacsony személyzet miatt olyan gyorsan uralkodott el a káosz , hogy még az örök optimista vezérigazgatónak is be kellett látnia , nem túl működőképes az ötlet .	vezérigazgatónak	26	Dat
# 10. Szűrőzés , digitális és analóg labortrükkök	labortrükkök	6	Nom
# A rák esetében a tanulmány bizonyítékai vegyes képet mutatnak , de kétségtelen , hogy szoros a kapcsolat a fokozott fizikai aktivitás és a vastagbélrák kialakulás esélyének csökkentése között mindkét nemnél .	nemnél	29	Ade
# A szakemberrel gyakran találkozhatunk intézményi , vállalati és lakossági befektetők számára rendezett szakmai konferenciákon , továbbképzéseken , emellett folyamatos médiaszereplésével aktív szerepet vállal a hazai befektetők gazdasági , pénzügyi és befektetési ismereteinek bővítésében .	továbbképzéseken	15	Sup
# Eddig három szervezetet , a Váralja Szövetséget , az Élőlánc Magyarországért Pártot , valamint a Gazdálkodó Családok Szövetségét jelölte meg mozgalma alapítójaként .	alapítójaként	21	Ess
# Érdeklődéssel olvasom , hogy animációval és multimédiával is foglalkozik .	animációval	4	Ins
# A lisztet összekeverjük a sütőporral , a vaníliás cukorral , és a reszelt citromhéjjal .	sütőporral	4	Ins
# Úgy hisszük apánk egy megtört ember volt , aki bánatában kiontotta önnön életét .	bánatában	9	Ine
# A szakember véleménye a kliens motivációjáról , együttműködési hajlandóságáról a kapcsolatfelvétel időpontjában .	hajlandóságáról	8	Del
# A szerethető , egyedi , downtempo zenét játszó zenekar jelenlegi tagjai Hártó Szilvia , Menyhárt Leó , Koroknay András és Asztalos Zoltán .	downtempo	5	Nom
# A gabionfalakat leggyakrabban támfalként , kerítés támfalaként használják , ilyenkor előre elkészített alapra rakják a kosarakat , majd erre a következő sorokat , amíg el nem érik a kívánt magasságot .	támfalaként	6	Ess
# A hír újabb mélységekbe lökte a telekommunikációs cég részvényeinek árfolyamát .	mélységekbe	3	Ill
# A tiltólistára kerülésre egy új kislemez lett a válasz .	kerülésre	2	Sub
# Miley nemrég költözött el Tennessee-ből és most Malibu-ban hódít tehetségével .	tehetségével	9	Ins
# ez a kérdés bizonyára napirendre kerül majd a pénzügyi terv felülvizsgálatakor .	felülvizsgálatakor	10	Tem
# Egy , az alapítás óta a szervezetnél lévő tag a fennálló helyzetet a Jobbik 2010 előtti kommunikációjához hasonlította .	szervezetnél	6	Ade
# Miért és mivel küzd ma egy vidéki egyetem , és hol a jövő a hallgatók számára a fővárostól egy aránylag messzi távolságban .	távolságban	21	Ine
# Egy effektet , a lábdobot vagy más hangzást kiválasztani és keverni csak minőségi felszereléssel lehet .	hangzást	7	Acc
# Különösen veszélyeztetettek az alkohol- és drogfogyasztók , de a számítógép- vagy játékgép-függő fiatalok , valamint a nagyon szoros párkapcsolatba bevonódó személyek egyaránt .	párkapcsolatba	18	Ill
# Egyébként a 99%-ot nem a cigányság összlakossághoz viszonyított arányából kifolyólag írtam , hanem mert az ilyen jellegű , ilyen módon elkövetett bűncselekmények elkövetői szinte mindig cigányok .	arányából	8	Ela
# A csodálatos átalakulás lényegében a polaritás elvén jön létre , azon az elméleten , hogy minden lény és megtestesülés magában hordozza önmaga kiegészítő , „ másik felét ” , azaz poláris ellentétjét .	megtestesülés	18	Nom
# A máriaremetei templomig , az ellenőrzőpontig együtt megyünk , és egy jót beszélgetünk .	templomig	2	Ter
# Következésképp egyáltalán NEM tanácsos megbízni a programban , fizetni érte pedig végképp nem ajánlott , mert nemcsak kidobott pénz lenne , hanem veszélyes kezekbe is juttathatja személyes adatait .	kezekbe	23	Ill
# A rendezői önmegvalósítást , színházi önmutogatást halálos vétek a gyerekekre rászabadítani , valamint azokat az produkciókat , amelyek a gyereknek ez is jó lesz alapelvével pénzkeresési céllal tehetség nélkül születtek .	önmutogatást	5	Acc
# A tanárok írhatnak egyedi jellemzéseket a diákokról , de rendelkezésükre állnak értékelési minták is , amikben az előre meghatározott kulcsszavakat lehet kiválasztani .	diákokról	6	Del
# A KÖZÉRDEKŰ BEJELENTÉSEK ÉS PANASZOK KEZELÉSÉNEK RENDJÉRŐL Jászberény Város Jegyzője tekintettel az európai uniós csatlakozással összefüggő egyes törvények módosításáról szóló 2004. évi XXIX. törvény 141 .	RENDJÉRŐL	6	Del
# A víz időközben nem hűlt ki , de én mégis úgy dideregtem mintha kihűlt volna … Innen a jobb lábamat már nem nagyon használtam , a műtött , de kiválóan funkcionáló ballal rugdostam a vizet , eléggé koordinálatlanul .	ballal	31	Ins
# Egy fiatal politikai párt vezetője behatolt az Origo szerkesztőségébe , hogy fenyegető stílusban számon kérje az újságírókat a pártról és annak pénzügyeiről szóló cikk miatt .	szerkesztőségébe	8	Ill
# 70-kilogrammos kadettek között Plesovszki Milán , juniorban Szilasi János szerzett aranyat a klubnak .	juniorban	6	Ine
# ( 16) Az a pedagógus , aki e törvény hatálybalépésekor az ötvenkettedik életévét betöltötte , pedagógus-továbbképzésben történõ részvételre nem kötelezhetõ .	hatálybalépésekor	9	Tem
# Az alperes fellebbezésében az elsıfokú ítélet megváltoztatását , a kereset elutasítását kérte .	fellebbezésében	2	Ine
# Munkaviszony létesítésekor a legtöbb munkáltató próbaidőt köt ki , hogy jobban megismerhesse a munkavállalót és annak szakmai kvalitásait , személyiségét .	létesítésekor	1	Tem
# Lényeges , hogy a logót minőségveszteség nélkül tudjuk nagyítani , ugyanis a cég logójának ugyanúgy kell kinéznie egy levélpapíron , egy weboldalon , és egy óriásplakáton is !	logójának	13	Dat
# Ez még – saját elmondása szerint – a Morgan Stanley-nek abban az időszakában volt , amikor még nem alakult át az egész bankszektor a Wall Street farkasává .	farkasává	26	Tra
# Alapításakor , 2004-ben Mark néhány évfolyamtársával dolgozott össze egy olyan oldal megalkotása céljából , ahol a Harvard Egyetem tanulói kapcsolatba léphetnek egymással .	Alapításakor	0	Tem
# Az utasok eligazodását segítheti a Debrecen Airport letölthető applikációja is , amelyben az összes repülőtéri szolgáltatásról tájékozódhatnak a nap 24 órájában .	szolgáltatásról	15	Del
# Az meg még kevésbé szopás , hogy a hangzásért felelős Sándor Dániel egy ideje az Isten Háta Mögött-ben is építi renoméját , így tehát matematikai képletekkel levezethető , mekkora kvltbandának is számít régi csapata hetedhéthatáron innen és onnan .	hangzásért	8	Cau
# Ezek a növények idegentermékenyülők , ezért a kiválasztott fajta bimbó korban tüllzacskóval szigetelt virágait kinyílásuk után mesterségesen összeporozzuk ( az egyik növény virágáról szedett pollent a másik növény virágjának bibéjére kenjük ) .	virágáról	22	Del
# Karvalits Ferenc , az MNB alelnöke hétfői sajtótájékoztatóján azt mondta : a magyar gazdaság változatlanul lassan növekszik , és az inflácó csökkenése sem gyorsult .	inflácó	20	Nom
# Épp saját regényen dolgozik , ami halakról fog szólni és ebben is nagy szerepe van a tanítónénijének .	regényen	2	Sup
# Zárásként egy közös zenélés , éneklés következett különböző hangszerekkel , melyeken hallgatónk ( Józsi ) énekelt és zenélt ( gitárral , dobolással ) .	hangszerekkel	8	Ins
# Azt már eddig is megszokhattuk , hogy a demokráciáért és az emberi jogokért aggódó gittegyletek rendre elfogult , a valósággal köszönőviszonyban sem lévő megállapításokat tesznek a világ országaival kapcsolatban .	demokráciáért	8	Cau
# Most meg egy egyszerű , de talpraesett bonni kávéházas miatt visszavonultak .	kávéházas	8	Nom
# A sérülésnek van egy lelket facsaró kegyetlensége .	sérülésnek	1	Dat
# A használt lakókocsik vásárlásakor a futott kilométerek számánál jobban kell figyelni a berendezés állagára .	vásárlásakor	3	Tem
# azokról a lehetőségekről , technikai eszközökről , amelyekkel még a szerződéses nyilatkozat elküldését megelőzően kijavíthatók az esetleges hibák .	eszközökről	5	Del
# Tudta , hogy egy szépségverseny jó kiindulási alap lehet az ismertséghez és az ügynökök figyelméhez , ezért indult az 1978-as Miss Orange County szépségversenyen és meg is nyerte azt .	figyelméhez	14	All
# Eljárási költség megtérítéséről nem kellett dönteni , mert az eljárás során ilyen költség nem merült fel .	megtérítéséről	2	Del
# Maffiák , kartellek , meg a tudatlan suttyók végül is azt csinálnak a mindenféle puncs-panccsal , amit csak akarnak , míg mindenki be nem csavarodik , beteggé nem lesz , és bele nem döglik , végül ?	puncs-panccsal	14	Ins
# Miután lerázta a bandát , visszatért a lokálhoz , a megszúrt Ivan Pesic testét a veséjénél elszorította , csökkentve ezzel a vérzést , majd vállára kapva a kórházig szaladt a kétméteres kapussal .	kórházig	27	Ter
# ( 1150 k. ) , a cefalui ( 1148) és a monrealei szegyh .	cefalui	6	Nom
# Ha azonban a mért görbéket az adott görbe +30 mv-nál mért vezet képesség értékére , mint maximumra normalizáltuk , a kapott vezet képesség-feszültség összefüggések nem különböztek egymástól ( 4/C. ábra ) .	maximumra	16	Sub
# A helység párttitkáráról volt szó .	párttitkáráról	2	Del
# Egy hosszabb , több éves munkaviszony esetén könnyen előfordulhat , hogy a munkáltató a versenytilalom ellenértékeként végül nagyobb összeget fizet meg a munkavállaló részére , mintha nem havonta fizetne , hanem csupán a munkaviszony megszűnésekor .	megszűnésekor	34	Tem
# Delben 10 solert ebedeltunk 1/4 csirket , krumplival , salataval , fagyival es inka kolaval .	kolaval	14	Ins
# A fiuk a banyaban kevesen dolgoznak !	banyaban	3	Sup
# Szóval , itt csak annyi a dolga , hogy 1,5 dl langyos vízbe tesz egy púpozott evőkanál lisztet , egy kiskanál kristálycukrot és az élesztőt belemorzsolva .	kristálycukrot	21	Acc
# Kínálatunkban megtalálhatók a legegyszerűbb diszk alapú DAS és NAS rendszerek és a legnagyobb SAN architektúrába tartozó tárolók , illetve a különböző szalagos rendszerek is .	architektúrába	14	Ill
# Ahogy korábban megírtuk , a tárgy meglepetés volt a Főúri utazások , úti kalandok kiállítás két éves évfordulós ünnepségéig .	ünnepségéig	18	Ter
# 2009 január 20-án , a beiktatási bálon Barack ésMichelle Obamaelső táncánál , Beyoncé énekelhette el nekik Etta James  At Last " című dalát .' because subtoken_end_idx exceeds tokenized length.
# Processed and saved representation for token 'tárult' in sentence: 'Az erdőből való kijutáskor idilli pannon táj tárult elénk , lankák , rétek , művelt földek , kis falu ... szép látványt nyújtott .'
# Processed and saved representation for token 'jött' in sentence: 'Az LMP frakciója egy olyan szövetség , amely a magyar politika megújításáért jött létre – mondta keddi , az Országgyűlés alakuló ülését követően tartott sajtótájékoztatóján Szél Bernadett frakcióvezető .'
# Skipping token ',' in sentence ' Az építészet valósága a teste : az , ami konkrét , ami formává , tömeggé , és térré vált .	formává	13	Tra
# Az Óvodák és Kollégium főkönyvi könyvelésének alapját az ún. könyvelési támlapok ,- melyek az alapbizonylatok kontírozása alapján készülő összesítő táblázatok- biztosítják .	könyvelésének	5	Dat
# Közben azonban az állami kézbe került kórházaknál folyamatosan járnak le a különféle szállítási szerződések .	kórházaknál	6	Ade
# Orosvári olyan fontos részletekre is gondolt , hogy olyantól rendeljen , aki biztosítani tudja , hogy minden megyeszékhelyen javítani vagy cserélni tudják majd az ágyakat , ha később erre szükség lenne .	megyeszékhelyen	17	Sup
# Miki Satoshi többi filmjéhez hasonlóan ez sem elsősorban a színészi játék terén emelkedik ki , hiszen vígjátékhoz méltóan mindenki egy kicsit túljátsza a szerepét , bár közel sincs akkora grimaszolás , mint a hongkongi komédiákban .	filmjéhez	3	All
# Volt idő mikor még nem ez volt a trend , de én is csak ezt látom , ismerősöknél , idegeneknél , imádnak nekem mesélni , minden korosztály .	ismerősöknél	17	Ade
# Vágjon bele az előadásába !	előadásába	3	Ill
# A Népszabadság kiadója , a Mediaworks szombattól függesztette fel a nyomtatott lap és a Népszabadság Online kiadását “ a lap új koncepciójának kialakításáig , illetve megvalósításáig ” – állt a hivatalos közleményben .	megvalósításáig	25	Ter
# A ransomware-ek jellegzetessége , hogy zárolják a gépen tárolt adatainkat , és azokat csak váltságdíjért cserébe oldják fel a támadók .	váltságdíjért	14	Cau
# Pillanatig sem csodálkozom , hogy úgy en bloc ez nem segíti elő a véleménypolarozációt .	Pillanatig	0	Ter
# Idővel ő is képes lesz kezelni a helyzetet , megtanulja , hogyan kell viselkedni az egyik óvónénivel és hogyan a másikkal .	óvónénivel	16	Ins
# A kitelepítésről , internálásról , illetve a katonai munkaszolgálatról 4.3 .	kitelepítésről	1	Del
# Halat a horgászoktól ?	horgászoktól	2	Abl
# - Különösen fontos ilyenkor a törzs tartóizmainak , a hát- és a hasizomnak az erősítése – ebben hatalmas segítséget jelenthet a szakorvos , a személyi edzők , a gyógytornász által felépített mozgásprogram .	hasizomnak	12	Dat
# Akik először vettek rszt gyertyás körmeneten , azoknak egy letre maradandó lmnyt nyújtott .	rszt	3	Acc
# Próbálkozott már a cégvezér automatizált gyárakkal , de ezekben a drasztikusan alacsony személyzet miatt olyan gyorsan uralkodott el a káosz , hogy még az örök optimista vezérigazgatónak is be kellett látnia , nem túl működőképes az ötlet .	vezérigazgatónak	26	Dat
# 10. Szűrőzés , digitális és analóg labortrükkök	labortrükkök	6	Nom
# A rák esetében a tanulmány bizonyítékai vegyes képet mutatnak , de kétségtelen , hogy szoros a kapcsolat a fokozott fizikai aktivitás és a vastagbélrák kialakulás esélyének csökkentése között mindkét nemnél .	nemnél	29	Ade
# A szakemberrel gyakran találkozhatunk intézményi , vállalati és lakossági befektetők számára rendezett szakmai konferenciákon , továbbképzéseken , emellett folyamatos médiaszereplésével aktív szerepet vállal a hazai befektetők gazdasági , pénzügyi és befektetési ismereteinek bővítésében .	továbbképzéseken	15	Sup
# Eddig három szervezetet , a Váralja Szövetséget , az Élőlánc Magyarországért Pártot , valamint a Gazdálkodó Családok Szövetségét jelölte meg mozgalma alapítójaként .	alapítójaként	21	Ess
# Érdeklődéssel olvasom , hogy animációval és multimédiával is foglalkozik .	animációval	4	Ins
# A lisztet összekeverjük a sütőporral , a vaníliás cukorral , és a reszelt citromhéjjal .	sütőporral	4	Ins
# Úgy hisszük apánk egy megtört ember volt , aki bánatában kiontotta önnön életét .	bánatában	9	Ine
# A szakember véleménye a kliens motivációjáról , együttműködési hajlandóságáról a kapcsolatfelvétel időpontjában .	hajlandóságáról	8	Del
# A szerethető , egyedi , downtempo zenét játszó zenekar jelenlegi tagjai Hártó Szilvia , Menyhárt Leó , Koroknay András és Asztalos Zoltán .	downtempo	5	Nom
# A gabionfalakat leggyakrabban támfalként , kerítés támfalaként használják , ilyenkor előre elkészített alapra rakják a kosarakat , majd erre a következő sorokat , amíg el nem érik a kívánt magasságot .	támfalaként	6	Ess
# A hír újabb mélységekbe lökte a telekommunikációs cég részvényeinek árfolyamát .	mélységekbe	3	Ill
# A tiltólistára kerülésre egy új kislemez lett a válasz .	kerülésre	2	Sub
# Miley nemrég költözött el Tennessee-ből és most Malibu-ban hódít tehetségével .	tehetségével	9	Ins
# ez a kérdés bizonyára napirendre kerül majd a pénzügyi terv felülvizsgálatakor .	felülvizsgálatakor	10	Tem
# Egy , az alapítás óta a szervezetnél lévő tag a fennálló helyzetet a Jobbik 2010 előtti kommunikációjához hasonlította .	szervezetnél	6	Ade
# Miért és mivel küzd ma egy vidéki egyetem , és hol a jövő a hallgatók számára a fővárostól egy aránylag messzi távolságban .	távolságban	21	Ine
# Egy effektet , a lábdobot vagy más hangzást kiválasztani és keverni csak minőségi felszereléssel lehet .	hangzást	7	Acc
# Különösen veszélyeztetettek az alkohol- és drogfogyasztók , de a számítógép- vagy játékgép-függő fiatalok , valamint a nagyon szoros párkapcsolatba bevonódó személyek egyaránt .	párkapcsolatba	18	Ill
# Egyébként a 99%-ot nem a cigányság összlakossághoz viszonyított arányából kifolyólag írtam , hanem mert az ilyen jellegű , ilyen módon elkövetett bűncselekmények elkövetői szinte mindig cigányok .	arányából	8	Ela
# A csodálatos átalakulás lényegében a polaritás elvén jön létre , azon az elméleten , hogy minden lény és megtestesülés magában hordozza önmaga kiegészítő , „ másik felét ” , azaz poláris ellentétjét .	megtestesülés	18	Nom
# A máriaremetei templomig , az ellenőrzőpontig együtt megyünk , és egy jót beszélgetünk .	templomig	2	Ter
# Következésképp egyáltalán NEM tanácsos megbízni a programban , fizetni érte pedig végképp nem ajánlott , mert nemcsak kidobott pénz lenne , hanem veszélyes kezekbe is juttathatja személyes adatait .	kezekbe	23	Ill
# A rendezői önmegvalósítást , színházi önmutogatást halálos vétek a gyerekekre rászabadítani , valamint azokat az produkciókat , amelyek a gyereknek ez is jó lesz alapelvével pénzkeresési céllal tehetség nélkül születtek .	önmutogatást	5	Acc
# A tanárok írhatnak egyedi jellemzéseket a diákokról , de rendelkezésükre állnak értékelési minták is , amikben az előre meghatározott kulcsszavakat lehet kiválasztani .	diákokról	6	Del
# A KÖZÉRDEKŰ BEJELENTÉSEK ÉS PANASZOK KEZELÉSÉNEK RENDJÉRŐL Jászberény Város Jegyzője tekintettel az európai uniós csatlakozással összefüggő egyes törvények módosításáról szóló 2004. évi XXIX. törvény 141 .	RENDJÉRŐL	6	Del
# A víz időközben nem hűlt ki , de én mégis úgy dideregtem mintha kihűlt volna … Innen a jobb lábamat már nem nagyon használtam , a műtött , de kiválóan funkcionáló ballal rugdostam a vizet , eléggé koordinálatlanul .	ballal	31	Ins
# Egy fiatal politikai párt vezetője behatolt az Origo szerkesztőségébe , hogy fenyegető stílusban számon kérje az újságírókat a pártról és annak pénzügyeiről szóló cikk miatt .	szerkesztőségébe	8	Ill
# 70-kilogrammos kadettek között Plesovszki Milán , juniorban Szilasi János szerzett aranyat a klubnak .	juniorban	6	Ine
# ( 16) Az a pedagógus , aki e törvény hatálybalépésekor az ötvenkettedik életévét betöltötte , pedagógus-továbbképzésben történõ részvételre nem kötelezhetõ .	hatálybalépésekor	9	Tem
# Az alperes fellebbezésében az elsıfokú ítélet megváltoztatását , a kereset elutasítását kérte .	fellebbezésében	2	Ine
# Munkaviszony létesítésekor a legtöbb munkáltató próbaidőt köt ki , hogy jobban megismerhesse a munkavállalót és annak szakmai kvalitásait , személyiségét .	létesítésekor	1	Tem
# Lényeges , hogy a logót minőségveszteség nélkül tudjuk nagyítani , ugyanis a cég logójának ugyanúgy kell kinéznie egy levélpapíron , egy weboldalon , és egy óriásplakáton is !	logójának	13	Dat
# Ez még – saját elmondása szerint – a Morgan Stanley-nek abban az időszakában volt , amikor még nem alakult át az egész bankszektor a Wall Street farkasává .	farkasává	26	Tra
# Alapításakor , 2004-ben Mark néhány évfolyamtársával dolgozott össze egy olyan oldal megalkotása céljából , ahol a Harvard Egyetem tanulói kapcsolatba léphetnek egymással .	Alapításakor	0	Tem
# Az utasok eligazodását segítheti a Debrecen Airport letölthető applikációja is , amelyben az összes repülőtéri szolgáltatásról tájékozódhatnak a nap 24 órájában .	szolgáltatásról	15	Del
# ...
# A ransomware-ek jellegzetessége , hogy zárolják a gépen tárolt adatainkat , és azokat csak váltságdíjért cserébe oldják fel a támadók .	váltságdíjért	14	Cau
# Pillanatig sem csodálkozom , hogy úgy en bloc ez nem segíti elő a véleménypolarozációt .	Pillanatig	0	Ter
# Idővel ő is képes lesz kezelni a helyzetet , megtanulja , hogyan kell viselkedni az egyik óvónénivel és hogyan a másikkal .	óvónénivel	16	Ins
# A kitelepítésről , internálásról , illetve a katonai munkaszolgálatról 4.3 .	kitelepítésről	1	Del
# Halat a horgászoktól ?	horgászoktól	2	Abl
# - Különösen fontos ilyenkor a törzs tartóizmainak , a hát- és a hasizomnak az erősítése – ebben hatalmas segítséget jelenthet a szakorvos , a személyi edzők , a gyógytornász által felépített mozgásprogram .	hasizomnak	12	Dat
# Akik először vettek rszt gyertyás körmeneten , azoknak egy letre maradandó lmnyt nyújtott .	rszt	3	Acc
# Próbálkozott már a cégvezér automatizált gyárakkal , de ezekben a drasztikusan alacsony személyzet miatt olyan gyorsan uralkodott el a káosz , hogy még az örök optimista vezérigazgatónak is be kellett látnia , nem túl működőképes az ötlet .	vezérigazgatónak	26	Dat
# 10. Szűrőzés , digitális és analóg labortrükkök	labortrükkök	6	Nom
# A rák esetében a tanulmány bizonyítékai vegyes képet mutatnak , de kétségtelen , hogy szoros a kapcsolat a fokozott fizikai aktivitás és a vastagbélrák kialakulás esélyének csökkentése között mindkét nemnél .	nemnél	29	Ade
# A szakemberrel gyakran találkozhatunk intézményi , vállalati és lakossági befektetők számára rendezett szakmai konferenciákon , továbbképzéseken , emellett folyamatos médiaszereplésével aktív szerepet vállal a hazai befektetők gazdasági , pénzügyi és befektetési ismereteinek bővítésében .	továbbképzéseken	15	Sup
# Eddig három szervezetet , a Váralja Szövetséget , az Élőlánc Magyarországért Pártot , valamint a Gazdálkodó Családok Szövetségét jelölte meg mozgalma alapítójaként .	alapítójaként	21	Ess
# Érdeklődéssel olvasom , hogy animációval és multimédiával is foglalkozik .	animációval	4	Ins
# A lisztet összekeverjük a sütőporral , a vaníliás cukorral , és a reszelt citromhéjjal .	sütőporral	4	Ins
# Úgy hisszük apánk egy megtört ember volt , aki bánatában kiontotta önnön életét .	bánatában	9	Ine
# A szakember véleménye a kliens motivációjáról , együttműködési hajlandóságáról a kapcsolatfelvétel időpontjában .	hajlandóságáról	8	Del
# A szerethető , egyedi , downtempo zenét játszó zenekar jelenlegi tagjai Hártó Szilvia , Menyhárt Leó , Koroknay András és Asztalos Zoltán .	downtempo	5	Nom
# A gabionfalakat leggyakrabban támfalként , kerítés támfalaként használják , ilyenkor előre elkészített alapra rakják a kosarakat , majd erre a következő sorokat , amíg el nem érik a kívánt magasságot .	támfalaként	6	Ess
# A hír újabb mélységekbe lökte a telekommunikációs cég részvényeinek árfolyamát .	mélységekbe	3	Ill
# A tiltólistára kerülésre egy új kislemez lett a válasz .	kerülésre	2	Sub
# Miley nemrég költözött el Tennessee-ből és most Malibu-ban hódít tehetségével .	tehetségével	9	Ins
# ez a kérdés bizonyára napirendre kerül majd a pénzügyi terv felülvizsgálatakor .	felülvizsgálatakor	10	Tem
# Egy , az alapítás óta a szervezetnél lévő tag a fennálló helyzetet a Jobbik 2010 előtti kommunikációjához hasonlította .	szervezetnél	6	Ade
# Miért és mivel küzd ma egy vidéki egyetem , és hol a jövő a hallgatók számára a fővárostól egy aránylag messzi távolságban .	távolságban	21	Ine
# Egy effektet , a lábdobot vagy más hangzást kiválasztani és keverni csak minőségi felszereléssel lehet .	hangzást	7	Acc
# Különösen veszélyeztetettek az alkohol- és drogfogyasztók , de a számítógép- vagy játékgép-függő fiatalok , valamint a nagyon szoros párkapcsolatba bevonódó személyek egyaránt .	párkapcsolatba	18	Ill
# Egyébként a 99%-ot nem a cigányság összlakossághoz viszonyított arányából kifolyólag írtam , hanem mert az ilyen jellegű , ilyen módon elkövetett bűncselekmények elkövetői szinte mindig cigányok .	arányából	8	Ela
# A csodálatos átalakulás lényegében a polaritás elvén jön létre , azon az elméleten , hogy minden lény és megtestesülés magában hordozza önmaga kiegészítő , „ másik felét ” , azaz poláris ellentétjét .	megtestesülés	18	Nom
# A máriaremetei templomig , az ellenőrzőpontig együtt megyünk , és egy jót beszélgetünk .	templomig	2	Ter
# Következésképp egyáltalán NEM tanácsos megbízni a programban , fizetni érte pedig végképp nem ajánlott , mert nemcsak kidobott pénz lenne , hanem veszélyes kezekbe is juttathatja személyes adatait .	kezekbe	23	Ill
# A rendezői önmegvalósítást , színházi önmutogatást halálos vétek a gyerekekre rászabadítani , valamint azokat az produkciókat , amelyek a gyereknek ez is jó lesz alapelvével pénzkeresési céllal tehetség nélkül születtek .	önmutogatást	5	Acc
# A tanárok írhatnak egyedi jellemzéseket a diákokról , de rendelkezésükre állnak értékelési minták is , amikben az előre meghatározott kulcsszavakat lehet kiválasztani .	diákokról	6	Del
# A KÖZÉRDEKŰ BEJELENTÉSEK ÉS PANASZOK KEZELÉSÉNEK RENDJÉRŐL Jászberény Város Jegyzője tekintettel az európai uniós csatlakozással összefüggő egyes törvények módosításáról szóló 2004. évi XXIX. törvény 141 .	RENDJÉRŐL	6	Del
# A víz időközben nem hűlt ki , de én mégis úgy dideregtem mintha kihűlt volna … Innen a jobb lábamat már nem nagyon használtam , a műtött , de kiválóan funkcionáló ballal rugdostam a vizet , eléggé koordinálatlanul .	ballal	31	Ins
# Egy fiatal politikai párt vezetője behatolt az Origo szerkesztőségébe , hogy fenyegető stílusban számon kérje az újságírókat a pártról és annak pénzügyeiről szóló cikk miatt .	szerkesztőségébe	8	Ill
# 70-kilogrammos kadettek között Plesovszki Milán , juniorban Szilasi János szerzett aranyat a klubnak .	juniorban	6	Ine
# ( 16) Az a pedagógus , aki e törvény hatálybalépésekor az ötvenkettedik életévét betöltötte , pedagógus-továbbképzésben történõ részvételre nem kötelezhetõ .	hatálybalépésekor	9	Tem
# Az alperes fellebbezésében az elsıfokú ítélet megváltoztatását , a kereset elutasítását kérte .	fellebbezésében	2	Ine
# Munkaviszony létesítésekor a legtöbb munkáltató próbaidőt köt ki , hogy jobban megismerhesse a munkavállalót és annak szakmai kvalitásait , személyiségét .	létesítésekor	1	Tem
# Lényeges , hogy a logót minőségveszteség nélkül tudjuk nagyítani , ugyanis a cég logójának ugyanúgy kell kinéznie egy levélpapíron , egy weboldalon , és egy óriásplakáton is !	logójának	13	Dat
# Ez még – saját elmondása szerint – a Morgan Stanley-nek abban az időszakában volt , amikor még nem alakult át az egész bankszektor a Wall Street farkasává .	farkasává	26	Tra
# Alapításakor , 2004-ben Mark néhány évfolyamtársával dolgozott össze egy olyan oldal megalkotása céljából , ahol a Harvard Egyetem tanulói kapcsolatba léphetnek egymással .	Alapításakor	0	Tem
# Az utasok eligazodását segítheti a Debrecen Airport letölthető applikációja is , amelyben az összes repülőtéri szolgáltatásról tájékozódhatnak a nap 24 órájában .	szolgáltatásról	15	Del
# Az meg még kevésbé szopás , hogy a hangzásért felelős Sándor Dániel egy ideje az Isten Háta Mögött-ben is építi renoméját , így tehát matematikai képletekkel levezethető , mekkora kvltbandának is számít régi csapata hetedhéthatáron innen és onnan .	hangzásért	8	Cau
# Ezek a növények idegentermékenyülők , ezért a kiválasztott fajta bimbó korban tüllzacskóval szigetelt virágait kinyílásuk után mesterségesen összeporozzuk ( az egyik növény virágáról szedett pollent a másik növény virágjának bibéjére kenjük ) .	virágáról	22	Del
# Karvalits Ferenc , az MNB alelnöke hétfői sajtótájékoztatóján azt mondta : a magyar gazdaság változatlanul lassan növekszik , és az inflácó csökkenése sem gyorsult .	inflácó	20	Nom
# Épp saját regényen dolgozik , ami halakról fog szólni és ebben is nagy szerepe van a tanítónénijének .	regényen	2	Sup
# Zárásként egy közös zenélés , éneklés következett különböző hangszerekkel , melyeken hallgatónk ( Józsi ) énekelt és zenélt ( gitárral , dobolással ) .	hangszerekkel	8	Ins
# Azt már eddig is megszokhattuk , hogy a demokráciáért és az emberi jogokért aggódó gittegyletek rendre elfogult , a valósággal köszönőviszonyban sem lévő megállapításokat tesznek a világ országaival kapcsolatban .	demokráciáért	8	Cau
# Most meg egy egyszerű , de talpraesett bonni kávéházas miatt visszavonultak .	kávéházas	8	Nom
# A sérülésnek van egy lelket facsaró kegyetlensége .	sérülésnek	1	Dat
# A használt lakókocsik vásárlásakor a futott kilométerek számánál jobban kell figyelni a berendezés állagára .	vásárlásakor	3	Tem
# azokról a lehetőségekről , technikai eszközökről , amelyekkel még a szerződéses nyilatkozat elküldését megelőzően kijavíthatók az esetleges hibák .	eszközökről	5	Del
# Tudta , hogy egy szépségverseny jó kiindulási alap lehet az ismertséghez és az ügynökök figyelméhez , ezért indult az 1978-as Miss Orange County szépségversenyen és meg is nyerte azt .	figyelméhez	14	All
# Eljárási költség megtérítéséről nem kellett dönteni , mert az eljárás során ilyen költség nem merült fel .	megtérítéséről	2	Del
# Maffiák , kartellek , meg a tudatlan suttyók végül is azt csinálnak a mindenféle puncs-panccsal , amit csak akarnak , míg mindenki be nem csavarodik , beteggé nem lesz , és bele nem döglik , végül ?	puncs-panccsal	14	Ins
# Miután lerázta a bandát , visszatért a lokálhoz , a megszúrt Ivan Pesic testét a veséjénél elszorította , csökkentve ezzel a vérzést , majd vállára kapva a kórházig szaladt a kétméteres kapussal .	kórházig	27	Ter
# ( 1150 k. ) , a cefalui ( 1148) és a monrealei szegyh .	cefalui	6	Nom
# Ha azonban a mért görbéket az adott görbe +30 mv-nál mért vezet képesség értékére , mint maximumra normalizáltuk , a kapott vezet képesség-feszültség összefüggések nem különböztek egymástól ( 4/C. ábra ) .	maximumra	16	Sub
# A helység párttitkáráról volt szó .	párttitkáráról	2	Del
# Egy hosszabb , több éves munkaviszony esetén könnyen előfordulhat , hogy a munkáltató a versenytilalom ellenértékeként végül nagyobb összeget fizet meg a munkavállaló részére , mintha nem havonta fizetne , hanem csupán a munkaviszony megszűnésekor .	megszűnésekor	34	Tem
# Delben 10 solert ebedeltunk 1/4 csirket , krumplival , salataval , fagyival es inka kolaval .	kolaval	14	Ins
# A fiuk a banyaban kevesen dolgoznak !	banyaban	3	Sup
# Szóval , itt csak annyi a dolga , hogy 1,5 dl langyos vízbe tesz egy púpozott evőkanál lisztet , egy kiskanál kristálycukrot és az élesztőt belemorzsolva .	kristálycukrot	21	Acc
# Kínálatunkban megtalálhatók a legegyszerűbb diszk alapú DAS és NAS rendszerek és a legnagyobb SAN architektúrába tartozó tárolók , illetve a különböző szalagos rendszerek is .	architektúrába	14	Ill
# Ahogy korábban megírtuk , a tárgy meglepetés volt a Főúri utazások , úti kalandok kiállítás két éves évfordulós ünnepségéig .	ünnepségéig	18	Ter
# 2009 január 20-án , a beiktatási bálon Barack ésMichelle Obamaelső táncánál , Beyoncé énekelhette el nekik Etta James  At Last " című dalát .' because subtoken_end_idx exceeds tokenized length.
# Skipping token 'értékbecslésének' in sentence ' Tudathasadásos állapot aktív dolgozóként a szépkorúságra gondolni .	szépkorúságra	6	Sub
# Ezek az öt milliméteresnél kisebb műanyagrészecskéket a halak tápláléknak hiszik , megeszik , valamint bekerülnek a városok vízvezetékrendszerébe is .	vízvezetékrendszerébe	17	Ill
# Igyekszünk tudásunkkal és munkáinkkal olyan megjelenést teremteni partnereinknek , melyet a legoptimálisabban alkalmazhatnak mind image , mind akció , mind eseményorientált felhasználás során .	munkáinkkal	3	Ins
# A történet , az események felelevenítésére használhatjuk a lánc- és a	felelevenítésére	5	Sub
# Extra laktató reggeli egy nyaralás emlékére Még valamikor kamaszkoromban , az akkori barátoméknál ettem először parasztreggelit .	barátoméknál	12	Ade
# HIRDETMÉNY NEMZETI FÖLDLPB TRTOZÓ FÖLDRÉSZLETEK NYILVÁNOS PÁLYÁZTTÁS , ILLETVE ÁRVERÉS MELLŐZÉSÉVEL TÖRTÉNŐ ÉRTÉKESÍTÉSÉNEK 2015/II .	HIRDETMÉNY	0	Nom
# BÜNTETÉS-VÉGREHAJTÁSI JOG TÉTELEK ÉS AZ ELSAJÁTÍTANDÓ JOGANYAG a Büntető Törvénykönyvről szóló 2012. évi C. törvény ( Btk. ) a büntetőeljárásról szóló 1998. évi XIX. törvény	JOGANYAG	6	Nom
# Április 18-án , vasárnap egy remeknek ígérkező kirándulásra várjuk a természetbarátokat a Sitkei-kápolnához .	Sitkei-kápolnához	12	All
# Beklen a Nagykunsági Civil Társadalomért Alapítvány 7 .	Társadalomért	4	Cau
# Robog tovább a Delta Vision retro turnénk , aminek heti főszereplője J. Goldenlane rendkívül szórakoztató poszt-apokaliptikus sci-fije , a Holdnak árnyéka .	Holdnak	19	Dat
# Konkoly Csaba leginkább két dolgot fájlal : taktikailag nem sikerült újítaniuk a meccs során , ráadásul hat-nyolc gólos hátrányban csapatként is szétestek a győriek , ami eddig nem igazán volt rájuk jellemző .	csapatként	19	Ess
# Egy valóban trú metálos pandát nem a WWF logójában , sokkal inkább a COF koncertjein lát !	logójában	8	Ine
# Etalont sajnos nem tudok senki éjjeliszekrényére helyezni .	éjjeliszekrényére	5	Sub
# Van valami ebben a Titansben , ami számomra lehengerlővé avanzsálja az egész gárdát és az egyik legerősebb címmé teszi a jelenlegi DC felhozatalban .	címmé	17	Tra
# A vaklicitnek köszönhetően 2012-ben 7,5 milliárd forintot takaríthattak meg a betegek , 2013-ban további 2,2 milliárd forinttal kellett kevesebbet fizetniük a gyógyszereikért .	gyógyszereikért	21	Cau
# Párosban Péter Ákossal izgalmas 3 szettes mérkőzésen kapott ki a döntőben a pécsi riválisoktól , és ezúttal a Szenjai – Pytel duó nyert .	riválisoktól	13	Abl
# Elsősorban nem is a lótól , inkább a lovastól , akinek eleinte nehezebben megy , hogy ráérezzen egy új ló mozgására , a segítségadások mértékére .	lótól	4	Abl
# Néhány misztikus visszavonul a világi tevékenységektől , és a teljes figyelmét az Istennel való misztikus egyesülésre összpontosítja .	tevékenységektől	5	Abl
# A voksokat hitek , elkötelezettségek irányítják , legkevésbé sem a tények , így nem szempont , hogy valójában mit képviselnek az egyes pártok , jelöltek .	voksokat	1	Acc
# A pecsétek gyűjtögetésének nem láttuk értelmét .	gyűjtögetésének	2	Dat
# 19 Fontos tudnivalók az OTDK-ra való nevezéssel kapcsolatban A helyi TDK konferencián tartott el adásával minden hallgató nevez a XXXI. Országos Tudományos Diákköri Konferenciára .	Konferenciára	23	Sub
# A THM számításnál az ügyfél által a pénzügyi intézménynek fizetett költségeket , valamint a harmadik személynek fizetett költségek közül az ügyfél által felajánlott fedezet értékbecslésének díját és lakásépítésnél a helyszíni szemlék díját kell figyelembe venni .	értékbecslésének	24	Dat
# Tájékoztató a teljesköltség-mutatóról a Nyugalom rendszeres díjas , klasszikus életbiztosításhoz Hatályos : 2017. január 1-jétől	életbiztosításhoz	9	All
# Mellékhatást egyáltalán semmit nem érzek , de az izmaimra jó hatása van.Így szeretném megkérdezni , hogy akkor nálam miért lehet hatásos , hisz nincs bizonyítottan myastheniám.Vagy miért nincs mellékhatása ?	izmaimra	8	Sub
# Az norvég ifjú balosokra győzelmi indulók helyett lebőgés várt .	balosokra	3	Sub
# Sűrűn , hatalmas pelyhekben hullt és kavargott a hó , s a reflektor fényében vidám zsibongó tánc vetült a zárka menyezetére .	pelyhekben	3	Ine
# Hangsúlyozta : az a céljuk , hogy a magyar ünnepekbe bekerüljön az ősökre való emlékezés .	ősökre	12	Sub
# Tanárként Debrecenben ( 12:26 ) , majd Sopronban helyezkedett el , s utóbbival kapcsolatban szól még a  kuruc-labanc " kulturális különbségről is ( 14:35 ) .' because subtoken_end_idx exceeds tokenized length.
# Processed and saved representation for token 'tehetünk' in sentence: 'Azt hittük , a szelektív hulladékgyűjtéssel sokat tehetünk a környezetért .'
# Processed and saved representation for token 'mondani' in sentence: 'Ugye elhangzott , talán a forrásoldalról a Pénzügyminisztériumnak kellene néhány szót megerősíteni , a büntetés-végrehajtástól , kérek mindenkit , hogy reagáljon , és azt hiszem , hogy a Nemzetbiztonsági Hivatalnál is az egyeztetésekről néhány szót mondani .'
# Processed and saved representation for token 'használja' in sentence: 'Engedélytől eltérő módon és célra használja c. )'
